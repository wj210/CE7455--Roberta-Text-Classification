# %% [markdown]
# Test performance of RoBerta on tweet_eval Emotion Dataset

# %% [markdown]
# Library packages

# %%
import torch
import torch.nn as nn 
import torch.optim as optim 
import numpy as np 
import matplotlib.pyplot as plt
import nltk
from tqdm.notebook import tqdm
from sklearn.metrics import accuracy_score, roc_curve, auc
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd
import os
from sklearn.metrics import balanced_accuracy_score
# !pip install autocorrect
import pickle
from autocorrect import Speller
import re
import string
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer 
# !pip install emoji
import emoji
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      |████████████████████████████████| 622 kB 4.2 MB/s
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622382 sha256=d307c689d33835d14b167c9fa74d0ac2759194e219e7263f260a0c1bd96180de
#   Stored in directory: /root/.cache/pip/wheels/54/d4/37/8244101ad50b0f7d9bffd93ce58ed7991ee1753b290923934b
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 4.2 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=16b8b3d9d6cc0694ccbefd7703b904f72acd3a1f234be6132ecafc2627e037ce
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
if torch.cuda.is_available():       
    device = torch.device("cuda")
    print(f'There are {torch.cuda.device_count()} GPU(s) available.')
    print('Device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# Device name: Tesla T4

# %%
## the HuggingFace libraries are not already installed in Colab
# !pip install transformers==4.17 # this will also install tokenizers 
# !pip install datasets
# Out:
# Collecting transformers==4.17
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 4.2 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.17) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.17) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.17) (4.11.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.17) (1.21.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.17) (4.64.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 52.0 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 7.2 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 62.0 MB/s
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 55.0 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.17) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.17) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.17) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.17) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.17) (3.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.17) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.17) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.17) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.17) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.17) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.17) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.17) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.12.1 transformers-4.17.0
# Collecting datasets
#   Downloading datasets-2.1.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 4.2 MB/s
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.5.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.5)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 52.2 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 61.1 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 73.1 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 80.5 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.0 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 60.6 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, responses, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.1.0 frozenlist-1.3.0 fsspec-2022.3.0 multidict-6.0.2 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2

# %%
import transformers
from transformers import AutoConfig, AutoModel, AutoTokenizer, RobertaForSequenceClassification,RobertaModel, Trainer, TrainingArguments
from transformers import AdamW, get_linear_schedule_with_warmup
import datasets
print(transformers.__version__)
# Out:
# 4.17.0

# %%
#Installing emot library
# !pip install emot #Importing libraries
import re
from emot.emo_unicode import UNICODE_EMOJI
# Out:
# Collecting emot
#   Downloading emot-3.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 19 kB/s
# Installing collected packages: emot
# Successfully installed emot-3.1

# %% [markdown]
# Load data

# %%
data = datasets.load_dataset("tweet_eval", "emotion")
# Out:
# Downloading builder script:   0%|          | 0.00/2.37k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# Downloading and preparing dataset tweet_eval/emotion (download: 472.47 KiB, generated: 511.52 KiB, post-processed: Unknown size, total: 984.00 KiB) to /root/.cache/huggingface/datasets/tweet_eval/emotion/1.1.0/12aee5282b8784f3e95459466db4cdf45c6bf49719c25cdb0743d71ed0410343...
# Downloading data files:   0%|          | 0/6 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/134k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/60.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/569 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/183 [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/6 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/3257 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1421 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/374 [00:00<?, ? examples/s]
# Dataset tweet_eval downloaded and prepared to /root/.cache/huggingface/datasets/tweet_eval/emotion/1.1.0/12aee5282b8784f3e95459466db4cdf45c6bf49719c25cdb0743d71ed0410343. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
### number of labels
num_labels = len(np.unique(data['train']['label']))
print (num_labels)
# Out:
# 4

# %%
# % splits of labels in train/validation/test
from collections import OrderedDict, Counter
class OrderedCounter(Counter, dict):
    'Counter that remembers the order elements are first encountered'
    def __repr__(self):
        return '%s(%r)' % (self.__class__.__name__, dict(self))

    def __reduce__(self):
        return self.__class__, (dict(self),)
data_len_train = len(data['train']['label'])
# print (data_len_train)
data_len_val = len(data['validation']['label'])
data_len_test = len(data['test']['label'])
# print (OrderedCounter(data['train']['label'])[19])

for i in range(num_labels):
  print ('Train labels : {}, percentage: {:.2f}'.format(i,(OrderedCounter(data['train']['label'])[i]/data_len_train)*100))
  print ('Val labels : {}, percentage: {:.2f}'.format(i,(OrderedCounter(data['validation']['label'])[i]/data_len_val)*100))
  print ('Test labels : {}, percentage: {:.2f}'.format(i,(OrderedCounter(data['test']['label'])[i]/data_len_test)*100))
# Out:
# Train labels : 0, percentage: 42.98
# Val labels : 0, percentage: 42.78
# Test labels : 0, percentage: 39.27
# Train labels : 1, percentage: 21.74
# Val labels : 1, percentage: 25.94
# Test labels : 1, percentage: 25.19
# Train labels : 2, percentage: 9.03
# Val labels : 2, percentage: 7.49
# Test labels : 2, percentage: 8.66
# Train labels : 3, percentage: 26.25
# Val labels : 3, percentage: 23.80
# Test labels : 3, percentage: 26.88

# %%
class CleanedEmotionsDataset():

    def __init__(self, tokenizer, df,max_length):
        super(CleanedEmotionsDataset, self).__init__()

        self.tokenizer = tokenizer
        self.max_seq_len = max_length
        self.input_ids, self.attention_mask,self.token_type_ids,self.label = self.get_input(df)
        

    def __len__(self):
        return len(self.label)
    
    def trunate_and_pad(self, tokens_seq):
        
        # Concat '[CLS]' at the beginning
        tokens_seq = ['[CLS]'] + tokens_seq     
        # Truncate sequences of which the lengths exceed the max_seq_len
        if len(tokens_seq) > self.max_seq_len:
            tokens_seq = tokens_seq[0 : self.max_seq_len]           
        # Generate padding
        padding = [0] * (self.max_seq_len - len(tokens_seq))       
        # Convert tokens_seq to token_ids
        input_ids = self.tokenizer.convert_tokens_to_ids(tokens_seq) # convert to id
        input_ids += padding   # add padding
        # Create attention_mask
        attention_mask = [1] * len(tokens_seq) + padding     
        # Create token_type_ids
        token_type_ids = [0] * (self.max_seq_len) # for identifying next sentence prediction
        
        assert len(input_ids) == self.max_seq_len
        assert len(attention_mask) == self.max_seq_len
        assert len(token_type_ids) == self.max_seq_len
        
        return input_ids, attention_mask, token_type_ids 

    # strip  @ with words and numbers
    def remove_pattern(self,input_txt):
        r = re.findall("@[\w]*", input_txt)
        for i in r:
            input_txt = re.sub(i, '', input_txt)
        input_txt = re.sub(r"\d+", "", input_txt)
        return input_txt  

    ## strip all @ and # with words following
    def strip_links(self,text):
        link_regex = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
        links = re.findall(link_regex, text)
        for link in links:
            text = text.replace(link[0], ', ')    
        return text
        
    def strip_all_entities(self,text):
        entity_prefixes = ['@','#']
        for separator in  string.punctuation:
            if separator not in entity_prefixes :
                text = text.replace(separator,' ')
        words = []
        for word in text.split():
            word = word.strip()
            if word:
                if word[0] not in entity_prefixes:
                    words.append(word)
        return ' '.join(words)

        # removing stopwords
    def removing_stopwords(self,text):
        text = repr(text)
        No_StopWords = [word for word in word_tokenize(text) if word.lower() not in stoplist ]
        # Convert list of tokens_without_stopwords to String type.
        words_string = ' '.join(No_StopWords)    
        return words_string

    ## lemmatization
    def lemmatization(self,text):
        # Converting words to their root forms
        lemma = [lemmatizer.lemmatize(w,'v') for w in w_tokenizer.tokenize(text)]
        return ' '.join(lemma)
    
    ## convert emoji to text
    def convert_emojis(self,text):
        for emot in UNICODE_EMOJI:
            text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
            text = text.replace('_', " ")
        return text

    def get_input(self,df):
        # df_tweet = self.clean_dataset(df['text'])
        ## clean off tags

        for i in range(len(df['text'])):
            df['text'][i] = df['text'][i].lower()
            df['text'][i] = self.remove_pattern(df['text'][i])
            df['text'][i] = self.convert_emojis(df['text'][i])
            # df['text'][i] = self.lemmatization(df['text'][i])
            # df['text'][i] = self.removing_stopwords(df['text'][i])
            # df['text'][i] = self.spell(self.lemmatization(df['text'][i]))
            
        tweet = df['text'].values
        # print (tweet)
        label = df['label'].values
        tokens_seq = list(map(self.tokenizer.tokenize,tweet))
        result = list(map(self.trunate_and_pad, tokens_seq))
        input_ids = [i[0] for i in result]
        attention_mask = [i[1] for i in result]
        token_type_ids = [i[2] for i in result]

        return (
               torch.Tensor(input_ids).type(torch.long), 
               torch.Tensor(attention_mask).type(torch.long),
               torch.Tensor(token_type_ids).type(torch.long), 
               torch.Tensor(label).type(torch.long)
               )

    def __getitem__(self, item):
        return self.input_ids[item], self.attention_mask[item],self.token_type_ids[item],self.label[item]

# %% [markdown]
# Model Class

# %%
class FinetuneModel(nn.Module):
    """Pretrained Model + classifier
    """
    def __init__(self, pretrained_model, d_in, d_h, d_out,dropout,freeze_pretrained=False,model_dir = None):
        super(FinetuneModel, self).__init__()

        # Instantiate BERT model
        
        self.pretrained_model = pretrained_model
        if model_dir != None:
            print ('True')
            self.pretrained_model.load_state_dict(model_dir,strict = False)

        # Instantiate a 2-layer feed-forward classifier
        self.classifier = nn.Sequential(
            nn.Linear(d_in, d_h),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(d_h, d_out)
        )

        # Freeze the encoder model
        if freeze_pretrained:
            for param in self.pretrained_model.parameters():
                param.requires_grad = False
            for param in self.pretrained_model.pooler.parameters():
                param.requires_grad = True
        
    def forward(self, input_ids, attention_mask):
        # Feed input to pretrained model
        pre_outputs = self.pretrained_model(input_ids = input_ids,attention_mask = attention_mask)
        hidden_state = pre_outputs[0]
        hidden_state = hidden_state[:,0,:]
        logits = self.classifier(hidden_state)
        return logits

# %% [markdown]
# Function to init model

# %%
def model_init(model_name,lr,weight_decay,batch_size,warmup,data):
  pretrained_model_emotions = RobertaModel.from_pretrained(model_name,config=config)
  model = FinetuneModel(pretrained_model_emotions,d_in,d_h,d_out,dropout,freeze_pretrained)
  model.to(device)
  param_optimizer = list(model.named_parameters())
  no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
  optimizer_grouped_parameters = [
          {
                  'params':[p for n, p in param_optimizer if not any(nd in n for nd in no_decay)],
                  'weight_decay':weight_decay
          },
          {
                  'params':[p for n, p in param_optimizer if any(nd in n for nd in no_decay)],
                  'weight_decay':0.0
          }
  ]
  optimizer = AdamW(optimizer_grouped_parameters, lr=lr, betas = (0.9,0.98),eps = 1e-6)
  total_steps = int(n_epochs * (len(data["train"]["text"]) / batch_size))
  warmup_steps = int(warmup * total_steps)
  scheduler = get_linear_schedule_with_warmup(
      optimizer,
      num_warmup_steps = warmup_steps, 
      num_training_steps = total_steps)
  
  return model,optimizer,scheduler

# %% [markdown]
# Training and Eval function

# %%
def set_seed(seed_value = 0):
    """Set seed for reproducibility.
    """
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)

def train(train_loader, model, optimizer, scheduler,loss_fct):
    model.train()
    train_losses = []
    correct_preds = 0
    pred_class = []
    actual_class = []
    tqdm_loader = tqdm(train_loader)
    for batch_index, (batch_seqs, batch_seq_masks, batch_seq_segments, batch_labels) in enumerate (tqdm_loader):
        model.zero_grad()
  

        input_ids = batch_seqs
        attention_mask = batch_seq_masks
        segments = batch_seq_segments
        labels = batch_labels

        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        segments = segments.to(device)
        labels = labels.to(device)

        logits = model(input_ids, attention_mask) # forward pass (batch_size, 1)
        loss = loss_fct(logits,labels)
        probs = nn.functional.softmax(logits,dim = -1)
        _,out_classes = torch.max(logits,dim = 1)
        ## for weighted accuracy
        pred_class.extend(out_classes.cpu().numpy())
        actual_class.extend(labels.cpu().numpy())

        correct = (out_classes == labels).sum()
        correct_preds += correct.item()
        train_losses.append(loss.item())

        loss.backward() # backward pass
        ## clip grad
        nn.utils.clip_grad_norm_(model.parameters(), max_gradient_norm)
        optimizer.step() # weights update
        scheduler.step()
        optimizer.zero_grad()
        
    train_loss = np.mean(train_losses)
    epoch_accuracy = correct_preds /len(train_loader.dataset)
    # epoch_accuracy = balanced_accuracy_score(actual_class,pred_class)

    return train_loss,epoch_accuracy

# %%
from sklearn.metrics import roc_auc_score, f1_score
def eval_multiclass(loader, model,loss_fct):
    model.eval()
    val_losses = []
    val_probs = []
    acc_correct = 0
    iter = 0
    log_interval = 100
    sigmoid = nn.Sigmoid()
    log_interval = 50
    count = 0
    val_labels = []
    val_targets = []
    pred_class = []
    actual_class = []
  
    # threshold = torch.tensor([0.5]).to(device)
    # loader = tqdm(loader)
    for (batch_seqs, batch_seq_masks, batch_seq_segments, batch_labels) in loader:
        input_ids = batch_seqs
        attention_mask = batch_seq_masks
        segments = batch_seq_segments
        labels = batch_labels

        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        labels = labels.to(device)
        segments = segments.to(device)
        # print (attention_mask.shape,labels.shape)
        # print (segments.shape)
        
        with torch.no_grad():
            valid_logits = model(input_ids, attention_mask) # raw logits
            # print (f'logits = {valid_logits}')
            # print(f'labels = {labels}')
            valid_loss = loss_fct(valid_logits,labels) # loss
            valid_probs = nn.functional.softmax(valid_logits,dim = -1)
            _,out_classes = torch.max(valid_logits,dim = 1)
            # if count % log_interval == 0:
            #   print (f'labels = {labels}')
            #   print (f'predicted labels = {out_classes}')
            f1_target = torch.argmax(valid_probs,dim= 1)
            # print (f1_target)
            correct = (out_classes == labels).sum()
            acc_correct += correct.item()
            # weighted accuracy

            pred_class.extend(out_classes.cpu().numpy())
            actual_class.extend(labels.cpu().numpy())


            # print (valid_probs.shape)
            val_probs.extend(valid_probs[:,:].cpu().numpy())
            val_labels.extend(labels.cpu().numpy())
            val_losses.append(valid_loss.item())
            val_targets.extend(f1_target.cpu().numpy())
            count +=1
            # print (count)
    val_loss = np.mean(val_losses)
    val_probs = np.array(val_probs)
    val_labels = np.array(val_labels)
    val_targets = np.array(val_targets)
    valid_accuracy = acc_correct/(len(loader.dataset))
    # valid_accuracy = balanced_accuracy_score(actual_class,pred_class)

    
    val_auc = 100* roc_auc_score(val_labels, val_probs, multi_class='ovr')
    val_f1_score = f1_score(val_labels,val_targets,average = 'weighted')

    return val_loss, val_auc, val_targets, val_labels,valid_accuracy,val_f1_score

# %% [markdown]
# Hyperparameters

# %%
# Hyper-parameters
model_name = "roberta-base" # we can change this, and play with any model from HuggingFace! 
# BERT-base: "bert-base-cased" #Sensitive to lower and upper case
# BERT-large: "bert-large-cased"
# RoBERTa-base: "roberta-base"
# RoBERTa-large: "roberta-large"
# etc ... 
max_length = 50
batch_size = 32
d_in = 768 # bert-base / roberta-base
d_h = 512 # 512 
d_out = num_labels # 2 classes so 1 is enough
dropout = 0.1
freeze_pretrained = False

# Training and Optimizer HP
# Hyper-parameters
n_epochs = 10
lr = 3e-05
warmup = 0.06
max_gradient_norm = 10
weight_decay = 0.1

# %% [markdown]
# Tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained( # robertatokenizer fast
    model_name,
    cache_dir = "."
)
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %% [markdown]
# Initialise EmotionDataset and dataloader

# %%
## lemmatization
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()
## speller
speller = Speller(lang = 'en')
# Convert to pandas df
data_train = datasets.Dataset.to_pandas(data["train"])
data_val = datasets.Dataset.to_pandas(data["validation"])
data_test = datasets.Dataset.to_pandas(data["test"])

train_dataset = CleanedEmotionsDataset(tokenizer, data_train,max_length)
val_dataset = CleanedEmotionsDataset(tokenizer, data_val,max_length)
test_dataset = CleanedEmotionsDataset(tokenizer, data_test,max_length)

# data loaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True) # shuffle the training set
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = batch_size, shuffle = False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## visualise text
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
        text = text.replace('_', " ")
    return text
def remove_pattern(input_txt):
    r = re.findall("@[\w]*", input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
    input_txt = re.sub(r"\d+", "", input_txt)
    return input_txt

def removing_stopwords(text):
    text = repr(text)
    No_StopWords = [word for word in word_tokenize(text) if word.lower() not in stoplist ]
    # Convert list of tokens_without_stopwords to String type.
    words_string = ' '.join(No_StopWords)    
    return words_string

def lemmatization(text):
    # Converting words to their root forms
    lemma = [lemmatizer.lemmatize(w,'v') for w in w_tokenizer.tokenize(text)]
    return ' '.join(lemma)

text = data['train']['text'][32]
print (f'Original text: {text}')
print (tokenizer.tokenize(text))

clean_text = convert_emojis(remove_pattern(text.lower()))
print (f'Cleaned text: {clean_text}')
print (tokenizer.tokenize(clean_text))
# Out:
# Original text: @user 'shit' doesn't even begin to describe these fiery little demons straight from hell 🌝🌚 ;)
# ['@', 'user', "Ġ'", 'shit', "'", 'Ġdoesn', "'t", 'Ġeven', 'Ġbegin', 'Ġto', 'Ġdescribe', 'Ġthese', 'Ġfiery', 'Ġlittle', 'Ġdemons', 'Ġstraight', 'Ġfrom', 'Ġhell', 'ĠðŁ', 'Į', 'Ŀ', 'ðŁ', 'Į', 'ļ', 'Ġ;)']
# Cleaned text:  'shit' doesn't even begin to describe these fiery little demons straight from hell full moon facenew moon face ;)
# ["Ġ'", 'shit', "'", 'Ġdoesn', "'t", 'Ġeven', 'Ġbegin', 'Ġto', 'Ġdescribe', 'Ġthese', 'Ġfiery', 'Ġlittle', 'Ġdemons', 'Ġstraight', 'Ġfrom', 'Ġhell', 'Ġfull', 'Ġmoon', 'Ġfac', 'en', 'ew', 'Ġmoon', 'Ġface', 'Ġ;)']

# %% [markdown]
# Config for Roberta model

# %%
### config
config = AutoConfig.from_pretrained(
    model_name, 
    output_hidden_states = True,
    output_attention = False
) 
# remember AutoConfig
config
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_hidden_states": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }

# %%
### Evaluate on clean data
# set seed
loss_fct = nn.CrossEntropyLoss()
set_seed(seed_value = 0)
model,optimizer,scheduler = model_init(model_name,lr,weight_decay,batch_size,warmup,data)
val_aucs = []
val_accs = []
best_score = 0.
patience_counter = 0
val_loss, val_auc, _, _, val_acc,val_f1_score= eval_multiclass(val_loader, model,loss_fct)
val_aucs.append(val_auc)
val_accs.append(val_acc)
print("\nEpoch 0 (before training) val loss: {:.4f}, AUC: {:.2f}, ACC: {:.4f}, f1_score : {:.2f}".format(val_loss, val_auc,val_acc*100,val_f1_score))
for epoch in range(1, n_epochs + 1):
    
    print("\nNew epoch, epoch {} / {}".format(epoch, n_epochs))

    # Training round
    train_loss,train_accuracy = train(train_loader, model, optimizer, scheduler,loss_fct)

    # Validation round
    val_loss, val_auc, _, _,val_acc,val_f1_score= eval_multiclass(val_loader, model,loss_fct)
    val_aucs.append(val_auc)

    print("Training: loss: {:.4f}, accuracy {:.4f}".format(train_loss,train_accuracy*100))
  
    print ("Validation: loss: {:.4f}, AUC: {:.2f}, ACC : {:.4f}, f1_score : {:.2f} (best ACC: {:.4f} at epoch {})"
    .format(val_loss, val_auc,val_acc*100,val_f1_score,np.max(np.array(val_acc)),np.argmax(np.array(val_acc*100))))

    print ('lr : {}'.format(scheduler.optimizer.param_groups[0]['lr']))
    if val_auc == np.max(np.array(val_aucs)):
        print("!! New best val AUC !!")
    if val_acc == np.max(np.array(val_acc)):
        print("!! New best val ACC !!")

## eval on test dataset
_, test_auc, test_probs, test_labels,test_acc,test_f1_score = eval_multiclass(test_loader, model,loss_fct)
print ("test AUC : {:.2f}".format(test_auc))
print ("test f1 score : {:.2f}".format(test_f1_score))
print ("test ACC : {:.2f}".format(test_acc*100))
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch 0 (before training) val loss: 1.4041, AUC: 46.81, ACC: 7.4866, f1_score : 0.01
#
# New epoch, epoch 1 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 1.0954, accuracy 50.5373
# Validation: loss: 0.6830, AUC: 90.76, ACC : 75.9358, f1_score : 0.74 (best ACC: 0.7594 at epoch 0)
# lr : 2.8713389121338915e-05
# !! New best val AUC !!
# !! New best val ACC !!
#
# New epoch, epoch 2 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.5862, accuracy 80.1351
# Validation: loss: 0.6033, AUC: 94.26, ACC : 78.0749, f1_score : 0.78 (best ACC: 0.7807 at epoch 0)
# lr : 2.5512552301255232e-05
# !! New best val AUC !!
# !! New best val ACC !!
#
# New epoch, epoch 3 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.3831, accuracy 86.8898
# Validation: loss: 0.6023, AUC: 94.37, ACC : 80.7487, f1_score : 0.81 (best ACC: 0.8075 at epoch 0)
# lr : 2.2311715481171546e-05
# !! New best val AUC !!
# !! New best val ACC !!
#
# New epoch, epoch 4 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.2731, accuracy 91.2803
# Validation: loss: 0.6050, AUC: 94.30, ACC : 82.6203, f1_score : 0.82 (best ACC: 0.8262 at epoch 0)
# lr : 1.9110878661087867e-05
# !! New best val ACC !!
#
# New epoch, epoch 5 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.1769, accuracy 94.1664
# Validation: loss: 0.6908, AUC: 94.35, ACC : 80.7487, f1_score : 0.81 (best ACC: 0.8075 at epoch 0)
# lr : 1.5910041841004184e-05
# !! New best val ACC !!
#
# New epoch, epoch 6 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.1163, accuracy 96.0700
# Validation: loss: 0.7775, AUC: 94.33, ACC : 79.1444, f1_score : 0.79 (best ACC: 0.7914 at epoch 0)
# lr : 1.2709205020920501e-05
# !! New best val ACC !!
#
# New epoch, epoch 7 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.0899, accuracy 97.0832
# Validation: loss: 0.8316, AUC: 94.06, ACC : 79.1444, f1_score : 0.80 (best ACC: 0.7914 at epoch 0)
# lr : 9.50836820083682e-06
# !! New best val ACC !!
#
# New epoch, epoch 8 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.0524, accuracy 98.3727
# Validation: loss: 0.8499, AUC: 94.41, ACC : 81.0160, f1_score : 0.81 (best ACC: 0.8102 at epoch 0)
# lr : 6.3075313807531386e-06
# !! New best val AUC !!
# !! New best val ACC !!
#
# New epoch, epoch 9 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.0415, accuracy 98.4955
# Validation: loss: 0.8866, AUC: 94.19, ACC : 79.1444, f1_score : 0.79 (best ACC: 0.7914 at epoch 0)
# lr : 3.1066945606694563e-06
# !! New best val ACC !!
#
# New epoch, epoch 10 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.0263, accuracy 99.1096
# Validation: loss: 0.9033, AUC: 94.28, ACC : 81.0160, f1_score : 0.81 (best ACC: 0.8102 at epoch 0)
# lr : 0.0
# !! New best val ACC !!
# test AUC : 94.58
# test f1 score : 0.83
# test ACC : 82.90

# %%
n_check = len(data["test"]["text"])
total_examples = dict()
total_correct = dict()
for i in range(n_check):
    test_label = test_labels[i]
    prob = test_probs[i]
    total_examples[test_label] = total_examples.get(test_label,0) + 1
    if test_label == int(prob):
      total_correct[int(prob)] = total_correct.get(int(prob),0) + 1
# print (total_examples)
# print (total_correct)
for i in range(num_labels):
  print ('total class {} correct is : {:.2f}%'.format(i,(total_correct[i]/total_examples[i])*100))

## class 2 lowest score
# Out:
# total class 0 correct is : 85.30%
# total class 1 correct is : 81.84%
# total class 2 correct is : 65.85%
# total class 3 correct is : 85.86%

# %% [markdown]
# Check how it classifies text

# %%
# Qualitative test samples
n_check = 10
label_name = dict({'0.0':'anger','1.0':'joy','2.0':'optimisim','3.0':'sadness'})
count = 5
for i in range(n_check):
    i+= i*(5+i)
    tweet = data["test"]["text"][i]
    test_label = test_labels[i]  
    prob = test_probs[i]
    print("\n" + "*"*20, "Tweet {}:".format(i+1))
    print("\n".join(sent_tokenize(tweet))) # print 1 sentence per line for reading easiness
    print("*"*10, "Label: {}".format(label_name[str(float(test_label))]))
    print ("*"*10, "Label: {}".format(test_label))
    print("*"*10, "Model prediction: {:.4f}".format(prob))
# Out:
# ******************** Tweet 1:
# #Deppression is real.
# Partners w/ #depressed people truly dont understand the depth in which they affect us.
# Add in #anxiety &amp;makes it worse
# ********** Label: sadness
# ********** Label: 3
# ********** Model prediction: 3.0000
#
# ******************** Tweet 8:
# In need of a change!
# #restless
# ********** Label: sadness
# ********** Label: 3
# ********** Model prediction: 3.0000
#
# ******************** Tweet 17:
# Its #amazing watching various news outlets showing mixed crowds of ppl watching #Eclipse with NO #racial tension.. #MSM can't hide this!
# ********** Label: joy
# ********** Label: 1
# ********** Model prediction: 1.0000
#
# ******************** Tweet 28:
# I cannot see a rational way of bearing a grudge to him for that.
# I do not.
# Maybe because I do not live by Netflix and I do not care...
# ********** Label: anger
# ********** Label: 0
# ********** Model prediction: 0.0000
#
# ******************** Tweet 41:
# BUT, I have offended so many people with the idea that conflicts and value judgments are separate that we need to have a talk.
# ********** Label: optimisim
# ********** Label: 2
# ********** Model prediction: 0.0000
#
# ******************** Tweet 56:
# Earth's sixth mass extinction event under way, scientists warn **basically  caused by Islamic Muslim terrorism which Obama dem- rats back*
# ********** Label: anger
# ********** Label: 0
# ********** Model prediction: 0.0000
#
# ******************** Tweet 73:
# omg i'm soooo fucking fuming
# ********** Label: anger
# ********** Label: 0
# ********** Model prediction: 0.0000
#
# ******************** Tweet 92:
# @user 😂 He looked like a sea weed version of cousin IT from adams family and was reaaaally tall.
# ********** Label: joy
# ********** Label: 1
# ********** Model prediction: 1.0000
#
# ******************** Tweet 113:
# @user @user @user I bet he needed to take an anime break and drink a Zima after all the furious typing.
# ********** Label: anger
# ********** Label: 0
# ********** Model prediction: 0.0000
#
# ******************** Tweet 136:
# Three more shifts then I start the next part of my tutorship in response #enjoyingthelastfewdays #excited #nervous #newchallanges
# ********** Label: joy
# ********** Label: 1
# ********** Model prediction: 1.0000

# %% [markdown]
# Performance on original text

# %%
class EmotionsDataset_Original():

    def __init__(self, tokenizer, df,max_length):
        super(EmotionsDataset_Original, self).__init__()

        self.tokenizer = tokenizer
        self.max_seq_len = max_length
        self.input_ids, self.attention_mask,self.token_type_ids,self.label = self.get_input(df)
        

    def __len__(self):
        return len(self.label)
    
    def trunate_and_pad(self, tokens_seq):
        
        # Concat '[CLS]' at the beginning
        tokens_seq = ['[CLS]'] + tokens_seq     
        # Truncate sequences of which the lengths exceed the max_seq_len
        if len(tokens_seq) > self.max_seq_len:
            tokens_seq = tokens_seq[0 : self.max_seq_len]           
        # Generate padding
        padding = [0] * (self.max_seq_len - len(tokens_seq))       
        # Convert tokens_seq to token_ids
        input_ids = self.tokenizer.convert_tokens_to_ids(tokens_seq) # convert to id
        input_ids += padding   # add padding
        # Create attention_mask
        attention_mask = [1] * len(tokens_seq) + padding     
        # Create token_type_ids
        token_type_ids = [0] * (self.max_seq_len) # for identifying next sentence prediction
        
        assert len(input_ids) == self.max_seq_len
        assert len(attention_mask) == self.max_seq_len
        assert len(token_type_ids) == self.max_seq_len
        
        return input_ids, attention_mask, token_type_ids 

    def get_input(self,df):          
        tweet = df['text'].values
        label = df['label'].values
        tokens_seq = list(map(self.tokenizer.tokenize,tweet))
        result = list(map(self.trunate_and_pad, tokens_seq))
        input_ids = [i[0] for i in result]
        attention_mask = [i[1] for i in result]
        token_type_ids = [i[2] for i in result]

        return (
               torch.Tensor(input_ids).type(torch.long), 
               torch.Tensor(attention_mask).type(torch.long),
               torch.Tensor(token_type_ids).type(torch.long), 
               torch.Tensor(label).type(torch.long)
               )

    def __getitem__(self, item):
        return self.input_ids[item], self.attention_mask[item],self.token_type_ids[item],self.label[item]

# %%
data_train = datasets.Dataset.to_pandas(data["train"])
data_val = datasets.Dataset.to_pandas(data["validation"])
data_test = datasets.Dataset.to_pandas(data["test"])

train_dataset = EmotionsDataset_Original(tokenizer, data_train,max_length)
val_dataset = EmotionsDataset_Original(tokenizer, data_val,max_length)
test_dataset = EmotionsDataset_Original(tokenizer, data_test,max_length)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True) # shuffle the training set
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = batch_size, shuffle = False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0fd6887311de> in <module>()
# ----> 1 data_train = datasets.Dataset.to_pandas(data["train"])
#       2 data_val = datasets.Dataset.to_pandas(data["validation"])
#       3 data_test = datasets.Dataset.to_pandas(data["test"])
#       4
#       5 train_dataset = EmotionsDataset_Original(tokenizer, data_train,max_length)
#
# NameError: name 'data' is not defined

# %%
### Evaluate on original text
# set seed
loss_fct = nn.CrossEntropyLoss()
set_seed(seed_value = 0)
model,optimizer,scheduler = model_init(model_name,lr,weight_decay,batch_size,warmup,data)
val_aucs = []
val_accs = []
best_score = 0.
patience_counter = 0
val_loss, val_auc, _, _, val_acc,val_f1_score= eval_multiclass(val_loader, model,loss_fct)
val_aucs.append(val_auc)
val_accs.append(val_acc)
print("\nEpoch 0 (before training) val loss: {:.4f}, AUC: {:.2f}, ACC: {:.4f}, f1_score : {:.2f}".format(val_loss, val_auc,val_acc*100,val_f1_score))
for epoch in range(1, n_epochs + 1):
    
    print("\nNew epoch, epoch {} / {}".format(epoch, n_epochs))

    # Training round
    train_loss,train_accuracy = train(train_loader, model, optimizer, scheduler,loss_fct)

    # Validation round
    val_loss, val_auc, _, _,val_acc,val_f1_score= eval_multiclass(val_loader, model,loss_fct)
    val_aucs.append(val_auc)

    print("Training: loss: {:.4f}, accuracy {:.4f}".format(train_loss,train_accuracy*100))
  
    print ("Validation: loss: {:.4f}, AUC: {:.2f}, ACC : {:.4f}, f1_score : {:.2f} (best ACC: {:.4f} at epoch {})"
    .format(val_loss, val_auc,val_acc*100,val_f1_score,np.max(np.array(val_acc)),np.argmax(np.array(val_acc*100))))

    print ('lr : {}'.format(scheduler.optimizer.param_groups[0]['lr']))
    if val_auc == np.max(np.array(val_aucs)):
        print("!! New best val AUC !!")
    if val_acc == np.max(np.array(val_acc)):
        print("!! New best val ACC !!")

## eval on test dataset
_, test_auc, test_probs, test_labels,test_acc,test_f1_score = eval_multiclass(test_loader, model,loss_fct)
print ("test AUC : {:.2f}".format(test_auc))
print ("test f1 score : {:.2f}".format(test_f1_score))
print ("test ACC : {:.2f}".format(test_acc*100))
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch 0 (before training) val loss: 1.4029, AUC: 49.07, ACC: 7.4866, f1_score : 0.01
#
# New epoch, epoch 1 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 1.0846, accuracy 51.7347
# Validation: loss: 0.6820, AUC: 90.99, ACC : 75.6684, f1_score : 0.75 (best ACC: 0.7567 at epoch 0)
# lr : 2.8713389121338915e-05
# !! New best val AUC !!
# !! New best val ACC !!
#
# New epoch, epoch 2 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.5767, accuracy 79.8588
# Validation: loss: 0.6267, AUC: 93.57, ACC : 78.6096, f1_score : 0.79 (best ACC: 0.7861 at epoch 0)
# lr : 2.5512552301255232e-05
# !! New best val AUC !!
# !! New best val ACC !!
#
# New epoch, epoch 3 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.3725, accuracy 87.5959
# Validation: loss: 0.6850, AUC: 92.99, ACC : 79.1444, f1_score : 0.79 (best ACC: 0.7914 at epoch 0)
# lr : 2.2311715481171546e-05
# !! New best val ACC !!
#
# New epoch, epoch 4 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.2577, accuracy 91.6795
# Validation: loss: 0.7548, AUC: 93.78, ACC : 78.3422, f1_score : 0.78 (best ACC: 0.7834 at epoch 0)
# lr : 1.9110878661087867e-05
# !! New best val AUC !!
# !! New best val ACC !!
#
# New epoch, epoch 5 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.1867, accuracy 93.7673
# Validation: loss: 0.7936, AUC: 93.37, ACC : 78.8770, f1_score : 0.79 (best ACC: 0.7888 at epoch 0)
# lr : 1.5910041841004184e-05
# !! New best val ACC !!
#
# New epoch, epoch 6 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.1283, accuracy 96.0393
# Validation: loss: 0.8905, AUC: 92.57, ACC : 77.2727, f1_score : 0.77 (best ACC: 0.7727 at epoch 0)
# lr : 1.2709205020920501e-05
# !! New best val ACC !!
#
# New epoch, epoch 7 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.0879, accuracy 97.4823
# Validation: loss: 0.9243, AUC: 92.92, ACC : 79.1444, f1_score : 0.79 (best ACC: 0.7914 at epoch 0)
# lr : 9.50836820083682e-06
# !! New best val ACC !!
#
# New epoch, epoch 8 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.0563, accuracy 98.3420
# Validation: loss: 1.0416, AUC: 92.97, ACC : 77.5401, f1_score : 0.78 (best ACC: 0.7754 at epoch 0)
# lr : 6.3075313807531386e-06
# !! New best val ACC !!
#
# New epoch, epoch 9 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.0374, accuracy 98.8947
# Validation: loss: 1.0087, AUC: 92.88, ACC : 79.4118, f1_score : 0.80 (best ACC: 0.7941 at epoch 0)
# lr : 3.1066945606694563e-06
# !! New best val ACC !!
#
# New epoch, epoch 10 / 10
#   0%|          | 0/102 [00:00<?, ?it/s]
# Training: loss: 0.0321, accuracy 99.1710
# Validation: loss: 1.0452, AUC: 92.88, ACC : 79.1444, f1_score : 0.79 (best ACC: 0.7914 at epoch 0)
# lr : 0.0
# !! New best val ACC !!
# test AUC : 94.50
# test f1 score : 0.82
# test ACC : 81.63

# %%
# Qualitative test samples
n_check = 10
label_name = dict({'0.0':'anger','1.0':'joy','2.0':'optimisim','3.0':'sadness'})
for i in range(n_check):
    tweet = data["test"]["text"][i]
    test_label = test_labels[i]  
    prob = test_probs[i]
    print("\n" + "*"*20, "Tweet {}:".format(i+1))
    print("\n".join(sent_tokenize(tweet))) # print 1 sentence per line for reading easiness
    print("*"*10, "Label: {}".format(label_name[str(float(test_label))]))
    print ("*"*10, "Label: {}".format(test_label))
    print("*"*10, "Model prediction: {:.4f}".format(prob))
# Out:
# ******************** Tweet 1:
# #Deppression is real.
# Partners w/ #depressed people truly dont understand the depth in which they affect us.
# Add in #anxiety &amp;makes it worse
# ********** Label: sadness
# ********** Label: 3
# ********** Model prediction: 3.0000
#
# ******************** Tweet 2:
# @user Interesting choice of words... Are you confirming that governments fund #terrorism?
# Bit of an open door, but still...
# ********** Label: anger
# ********** Label: 0
# ********** Model prediction: 0.0000
#
# ******************** Tweet 3:
# My visit to hospital for care triggered #trauma from accident 20+yrs ago and image of my dead brother in it.
# Feeling symptoms of #depression
# ********** Label: sadness
# ********** Label: 3
# ********** Model prediction: 3.0000
#
# ******************** Tweet 4:
# @user Welcome to #MPSVT!
# We are delighted to have you!
# #grateful #MPSVT #relationships
# ********** Label: joy
# ********** Label: 1
# ********** Model prediction: 1.0000
#
# ******************** Tweet 5:
# What makes you feel #joyful?
# ********** Label: joy
# ********** Label: 1
# ********** Model prediction: 1.0000
#
# ******************** Tweet 6:
# i am revolting.
# ********** Label: anger
# ********** Label: 0
# ********** Model prediction: 0.0000
#
# ******************** Tweet 7:
# Rin might ever appeared gloomy but to be a melodramatic person was not her thing.\n\nBut honestly, she missed her old friend.
# The special one.
# ********** Label: sadness
# ********** Label: 3
# ********** Model prediction: 3.0000
#
# ******************** Tweet 8:
# In need of a change!
# #restless
# ********** Label: sadness
# ********** Label: 3
# ********** Model prediction: 3.0000
#
# ******************** Tweet 9:
# @user @user #cmbyn does screen  August 4 &amp; 6 at #miff
# ********** Label: sadness
# ********** Label: 3
# ********** Model prediction: 1.0000
#
# ******************** Tweet 10:
# @user Get Donovan out of your soccer booth.
# He's awful.
# He's bitter.
# He makes me want to mute the tv.
# #horrid
# ********** Label: anger
# ********** Label: 0
# ********** Model prediction: 0.0000

# %% [markdown]
# Percentage accuracy in each class

# %%
n_check = len(data["test"]["text"])
total_examples = dict()
total_correct = dict()
for i in range(n_check):
    test_label = test_labels[i]
    prob = test_probs[i]
    total_examples[test_label] = total_examples.get(test_label,0) + 1
    if test_label == int(prob):
      total_correct[int(prob)] = total_correct.get(int(prob),0) + 1
# print (total_examples)
# print (total_correct)
for i in range(num_labels):
  print ('total class {} correct is : {:.2f}%'.format(i,(total_correct[i]/total_examples[i])*100))
# Out:
# total class 0 correct is : 84.05%
# total class 1 correct is : 82.12%
# total class 2 correct is : 70.73%
# total class 3 correct is : 81.15%

# %% [markdown]
# # Hyperparameter Fine-Tuning using Raytune

# %%
# !pip install ray==1.10.0
from ray.tune.schedulers import PopulationBasedTraining,ASHAScheduler
from ray import tune
from ray.tune import uniform, CLIReporter
from random import randint
import ray
# Out:
# Collecting ray==1.10.0
#   Downloading ray-1.10.0-cp37-cp37m-manylinux2014_x86_64.whl (59.6 MB)
#      |████████████████████████████████| 59.6 MB 1.2 MB/s
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (3.17.3)
# Collecting redis>=3.5.0
#   Downloading redis-4.2.2-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 78.4 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (7.1.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (1.0.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (1.21.5)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (1.44.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (4.3.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (21.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray==1.10.0) (3.6.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.28.1->ray==1.10.0) (1.15.0)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray==1.10.0) (4.11.3)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray==1.10.0) (4.1.1)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray==1.10.0) (4.0.2)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray==1.10.0) (21.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray==1.10.0) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray==1.10.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.4->redis>=3.5.0->ray==1.10.0) (3.0.8)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray==1.10.0) (5.6.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray==1.10.0) (0.18.1)
# Installing collected packages: deprecated, redis, ray
# Successfully installed deprecated-1.2.13 ray-1.10.0 redis-4.2.2

# %%
def load_data(config,data_dir = None):
    if load_data  == None:
        datasets.load_dataset("tweet_eval",'emotion')
    data_train = datasets.Dataset.to_pandas(data["train"])
    data_val = datasets.Dataset.to_pandas(data["validation"])
    data_test = datasets.Dataset.to_pandas(data["test"])
    ## Emotion dataset
    train_dataset = CleanedEmotionsDataset(tokenizer, data_train, config['max_length'])
    val_dataset = CleanedEmotionsDataset(tokenizer, data_val, config['max_length'])
    test_dataset = CleanedEmotionsDataset(tokenizer, data_test, config['max_length'])
    ## dataloader
    # train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True) # shuffle the training set
    # val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = batch_size, shuffle = False)
    # test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)
    print (len(data["train"]["text"]))
    return train_dataset,val_dataset,test_dataset,len(data["train"]["text"])

# %%
# Hyper-parameters
model_name = "roberta-base" # we can change this, and play with any model from HuggingFace! 
# BERT-base: "bert-base-cased" #Sensitive to lower and upper case
# BERT-large: "bert-large-cased"
# RoBERTa-base: "roberta-base"
# RoBERTa-large: "roberta-large"
# etc ... 
max_length = 50
batch_size = 32
d_in = 768 
d_h = 512 # 512 
d_out = num_labels 
dropout = 0.1
freeze_pretrained = False

# Training and Optimizer HP
# Hyper-parameters
n_epochs = 10
lr = 3e-05
warmup = 0.06
max_gradient_norm = 10
weight_decay = 0.1

# %%
tokenizer = AutoTokenizer.from_pretrained( # robertatokenizer fast
    model_name,
    cache_dir = "."
)
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
### config
config_model = AutoConfig.from_pretrained(
    model_name, 
    output_hidden_states = True,
    output_attention = False
)
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
def train_function(config, checkpoint_dir=None, data_dir=None):

    # if checkpoint_dir == None:
    #   checkpoint_dir = 'fine-tuned_model'
    ## define model
    seed_value = 0
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)
    model = RobertaModel.from_pretrained(model_name,config = config_model)
    model = FinetuneModel(model,d_in,config['d_h'],d_out,config['dropout'],freeze_pretrained) #pretrained_model, d_in, d_h, d_out, freeze_pretrained=False

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
    model.to(device)
    print (f'is GPU available? {torch.cuda.is_available()}')
    print (f'device used: {device}')
### Optimizer
    param_optimizer = list(model.named_parameters())
    no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
    optimizer_grouped_parameters = [
            {
                    'params':[p for n, p in param_optimizer if not any(nd in n for nd in no_decay)],
                    'weight_decay':config['weight_decay']
            },
            {
                    'params':[p for n, p in param_optimizer if any(nd in n for nd in no_decay)],
                    'weight_decay':0.0
            }
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=config['lr'],betas = (config['beta1'],config['beta2']),eps = config['eps'])
    criterion = nn.CrossEntropyLoss()

    # if checkpoint_dir:
    #     model_state, optimizer_state = torch.load(
    #         os.path.join(checkpoint_dir, "checkpoint"))
    #     model.load_state_dict(model_state)
    #     optimizer.load_state_dict(optimizer_state)

    trainset, valset,_,len_data = load_data(config,data_dir)
    ## scheduler
    total_steps = int(config['num_epochs'] * (len_data / config['batch_size'])) # get total_steps for scheduler
    warmup_steps = int(config['warmup'] * total_steps)
    scheduler = get_linear_schedule_with_warmup(
      optimizer,
      num_warmup_steps = warmup_steps, 
      num_training_steps = total_steps)

    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=int(config["batch_size"]),
        shuffle=True)
    valloader = torch.utils.data.DataLoader(
        valset,
        batch_size=int(config["batch_size"]),
        shuffle=False)
    ## Training ####
    for epoch in range(config['num_epochs']):  # loop over the dataset multiple times
        running_loss = 0.0
        epoch_steps = 0
        total = 0
        correct = 0
        for batch_index, (batch_seqs, batch_seq_masks, batch_seq_segments,batch_labels) in enumerate (trainloader):
            # get the inputs; data is a list of [inputs, labels]
            model.zero_grad()

            input_ids = batch_seqs
            attention_mask = batch_seq_masks
            labels = batch_labels

            input_ids = input_ids.to(device)
            attention_mask = attention_mask.to(device)
            labels = labels.to(device)

            outputs = model(input_ids,attention_mask)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            loss = criterion(outputs, labels)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), max_norm = config['max_gradient_norm'])
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()
            

            # print statistics
            running_loss += loss.item()
            epoch_steps += 1
            if batch_index % 10 == 0:  # print every 2000 mini-batches
                print("Epoch: {}, batch no: {} loss: {:.2f}, accuracy: {:.2f}%".format(epoch + 1, batch_index + 1,
                                                running_loss / epoch_steps,(correct/total)*100))
                running_loss = 0.0

        # Validation loss
        val_loss = 0.0
        val_steps = 0
        total = 0
        acc_correct = 0
        correct = 0
        running_loss = 0
        print ('------'*89)
        print ('Start Validating')
        print ('------'*89)
        for batch_index, (batch_seqs, batch_seq_masks, batch_seq_segments,batch_labels) in enumerate (valloader):
            # get the inputs; data is a list of [inputs, labels]
            with torch.no_grad():
                input_ids = batch_seqs
                attention_mask = batch_seq_masks
                labels = batch_labels

                input_ids = input_ids.to(device)
                attention_mask = attention_mask.to(device)
                labels = labels.to(device)

                outputs = model(input_ids,attention_mask)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                acc_correct += (predicted == labels).sum().item()
                correct = acc_correct
                loss = criterion(outputs, labels)

                val_loss += loss.cpu().numpy()
                val_steps += 1

            ### printing item
            running_loss += loss.item()
            if batch_index % 10 == 0:  # print every 2000 mini-batches
                print("Epoch: {}, batch no: {} loss: {:.2f}, accuracy: {:.2f}%".format(epoch + 1, batch_index + 1,
                                                running_loss / val_steps,(correct/total)*100))
                running_loss = 0.0
                
        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            print (f'checkpoint path : {path}')
            torch.save((model.state_dict(), optimizer.state_dict(),scheduler.state_dict()), path)
            print ('Model Saved!')
        accuracy = correct/(len(valloader.dataset))
        tune.report(loss=(val_loss / val_steps), accuracy=accuracy)
        ## scheduler
    # test_acc,test_loss = test_accuracy(model, device) # evaluate on test set
    # tune.report(loss = test_loss,accuracy = test_acc)
    print("Finished Training")

# %%
def test_accuracy(config,model, device="cpu"):
    _,_,testset,_ = load_data(config)

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=config['batch_size'], shuffle=False)
    criterion = nn.CrossEntropyLoss()
    correct = 0
    total = 0
    test_loss = 0.
    test_steps = 0
    with torch.no_grad():
        for batch_index, (batch_seqs, batch_seq_masks,batch_seq_segments, batch_labels) in enumerate (testloader):
      
            batch_seqs, batch_seq_masks,batch_labels = batch_seqs.to(device), batch_seq_masks.to(device), batch_labels.to(device)
            outputs = model(batch_seqs,batch_seq_masks)
            _, predicted = torch.max(outputs.data, 1)
            loss = criterion(outputs,batch_labels)
            total += batch_labels.size(0)
            correct += (predicted == batch_labels).sum().item()
            test_loss += loss.cpu().numpy()
            test_steps += 1

    return correct / total, test_loss/test_steps

# %% [markdown]
# # Tuning each hyperparameter separately.
# Learning rate, Weight decay and max grad norm, run for 5 trials each.

# %%
# Tune learning rate
config = {"num_epochs": 10,
          "lr": tune.loguniform(1e-5,3e-4),
          "batch_size": 32,
          "weight_decay": 0.1,
          "beta1": 0.9,
          "beta2": 0.98,
          "eps": 1e-6,
          "max_gradient_norm":10,
          "dropout": 0.1,
          "warmup":0.06,
          "d_h":512,
          "max_length": 50
          }

# %%
def main(num_samples=10,max_num_epochs =10, gpus_per_trial=1):
    # load_data()
    # ray.init()
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "accuracy", "training_iteration"])

    ## ASHA scheduler
    scheduler = ASHAScheduler(
        metric="accuracy",
        mode="max",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    
    result = tune.run(
        train_function,
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter = reporter,
        )

    best_trial = result.get_best_trial("accuracy", "max", "last")
    print("Best trial config for learning rate: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    best_trained_model = RobertaModel.from_pretrained(model_name,config = config_model)
    best_trained_model = FinetuneModel(best_trained_model,d_in,best_trial.config['d_h'],d_out,best_trial.config['dropout'],freeze_pretrained)
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state,scheduler_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_acc,test_loss = test_accuracy(best_trial.config,best_trained_model, device)
    print("Best trial test set accuracy: {} , test loss : {}".format(test_acc,test_loss))
    print (f'scheduler : {scheduler_state.keys()}')


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=5,max_num_epochs=10, gpus_per_trial=1)
# Out:
# 2022-04-18 13:56:51,513	INFO logger.py:606 -- pip install "ray[tune]" to see TensorBoard files.
# 2022-04-18 13:56:51,515	WARNING callback.py:115 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-04-18 13:56:52 (running for 00:00:00.66)
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Downloading:   0%|          | 2.30M/478M [00:00<00:20, 24.1MB/s]
# Downloading:   1%|          | 4.60M/478M [00:00<00:20, 23.8MB/s]
# == Status ==
# Current time: 2022-04-18 13:56:57 (running for 00:00:05.69)
# Memory usage on this node: 2.4/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
# Downloading:   2%|▏         | 10.3M/478M [00:00<00:12, 40.3MB/s]
# Downloading:   4%|▎         | 16.8M/478M [00:00<00:09, 50.9MB/s]
# Downloading:   5%|▍         | 22.9M/478M [00:00<00:08, 55.8MB/s]
# Downloading:   6%|▌         | 28.7M/478M [00:00<00:08, 57.4MB/s]
# Downloading:   7%|▋         | 35.1M/478M [00:00<00:07, 60.6MB/s]
# Downloading:   9%|▊         | 41.7M/478M [00:00<00:07, 63.2MB/s]
# Downloading:  10%|█         | 48.1M/478M [00:00<00:06, 64.7MB/s]
# Downloading:  11%|█▏        | 54.3M/478M [00:01<00:06, 64.2MB/s]
# Downloading:  13%|█▎        | 60.5M/478M [00:01<00:06, 64.4MB/s]
# Downloading:  14%|█▍        | 66.7M/478M [00:01<00:06, 63.7MB/s]
# Downloading:  15%|█▌        | 72.7M/478M [00:01<00:06, 63.3MB/s]
# Downloading:  17%|█▋        | 79.1M/478M [00:01<00:06, 64.4MB/s]
# Downloading:  18%|█▊        | 85.4M/478M [00:01<00:06, 64.9MB/s]
# Downloading:  19%|█▉        | 91.9M/478M [00:01<00:06, 65.9MB/s]
# Downloading:  21%|██        | 98.5M/478M [00:01<00:05, 66.6MB/s]
# Downloading:  22%|██▏       | 105M/478M [00:01<00:05, 67.1MB/s]
# Downloading:  23%|██▎       | 111M/478M [00:01<00:05, 67.2MB/s]
# Downloading:  25%|██▍       | 118M/478M [00:02<00:05, 67.5MB/s]
# Downloading:  26%|██▌       | 125M/478M [00:02<00:05, 68.3MB/s]
# Downloading:  27%|██▋       | 131M/478M [00:02<00:05, 68.7MB/s]
# Downloading:  29%|██▉       | 138M/478M [00:02<00:05, 69.0MB/s]
# Downloading:  30%|███       | 144M/478M [00:02<00:05, 66.8MB/s]
# Downloading:  32%|███▏      | 151M/478M [00:02<00:05, 67.3MB/s]
# Downloading:  33%|███▎      | 157M/478M [00:02<00:05, 66.9MB/s]
# Downloading:  34%|███▍      | 164M/478M [00:02<00:04, 67.7MB/s]
# Downloading:  36%|███▌      | 171M/478M [00:02<00:04, 67.7MB/s]
# Downloading:  37%|███▋      | 177M/478M [00:02<00:04, 66.9MB/s]
# Downloading:  38%|███▊      | 184M/478M [00:03<00:04, 67.6MB/s]
# Downloading:  40%|███▉      | 190M/478M [00:03<00:04, 62.1MB/s]
# Downloading:  41%|████      | 196M/478M [00:03<00:05, 54.9MB/s]
# Downloading:  42%|████▏     | 202M/478M [00:03<00:05, 54.2MB/s]
# Downloading:  43%|████▎     | 207M/478M [00:03<00:05, 53.8MB/s]
# Downloading:  44%|████▍     | 212M/478M [00:03<00:05, 50.6MB/s]
# Downloading:  45%|████▌     | 217M/478M [00:03<00:05, 49.1MB/s]
# Downloading:  46%|████▋     | 222M/478M [00:03<00:05, 46.2MB/s]
# Downloading:  47%|████▋     | 226M/478M [00:03<00:05, 45.8MB/s]
# Downloading:  48%|████▊     | 231M/478M [00:04<00:06, 43.2MB/s]
# Downloading:  49%|████▉     | 235M/478M [00:04<00:06, 40.3MB/s]
# Downloading:  50%|█████     | 239M/478M [00:04<00:05, 43.0MB/s]
# Downloading:  51%|█████     | 245M/478M [00:04<00:05, 46.8MB/s]
# Downloading:  52%|█████▏    | 249M/478M [00:04<00:05, 44.6MB/s]
# Downloading:  53%|█████▎    | 254M/478M [00:04<00:05, 41.1MB/s]
# Downloading:  54%|█████▍    | 258M/478M [00:04<00:05, 40.5MB/s]
# Downloading:  55%|█████▍    | 262M/478M [00:04<00:05, 42.6MB/s]
# Downloading:  56%|█████▌    | 266M/478M [00:05<00:05, 40.8MB/s]
# Downloading:  57%|█████▋    | 272M/478M [00:05<00:04, 44.4MB/s]
# Downloading:  58%|█████▊    | 276M/478M [00:05<00:04, 44.3MB/s]
# Downloading:  59%|█████▊    | 280M/478M [00:05<00:04, 44.4MB/s]
# Downloading:  60%|█████▉    | 284M/478M [00:05<00:04, 44.5MB/s]
# Downloading:  60%|██████    | 289M/478M [00:05<00:04, 43.4MB/s]
# Downloading:  61%|██████▏   | 293M/478M [00:05<00:04, 44.9MB/s]
# Downloading:  62%|██████▏   | 298M/478M [00:05<00:04, 45.0MB/s]
# Downloading:  63%|██████▎   | 302M/478M [00:05<00:04, 43.4MB/s]
# Downloading:  64%|██████▍   | 307M/478M [00:05<00:03, 45.2MB/s]
# Downloading:  65%|██████▌   | 312M/478M [00:06<00:03, 47.7MB/s]
# Downloading:  66%|██████▋   | 318M/478M [00:06<00:03, 51.3MB/s]
# Downloading:  68%|██████▊   | 323M/478M [00:06<00:03, 52.7MB/s]
# Downloading:  69%|██████▉   | 329M/478M [00:06<00:02, 55.5MB/s]
# == Status ==
# Current time: 2022-04-18 13:57:03 (running for 00:00:11.68)
# Memory usage on this node: 2.6/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
# Downloading:  70%|██████▉   | 334M/478M [00:06<00:02, 54.8MB/s]
# Downloading:  71%|███████   | 339M/478M [00:06<00:02, 51.0MB/s]
# Downloading:  72%|███████▏  | 345M/478M [00:06<00:02, 53.3MB/s]
# Downloading:  73%|███████▎  | 350M/478M [00:06<00:02, 51.7MB/s]
# Downloading:  74%|███████▍  | 356M/478M [00:06<00:02, 54.4MB/s]
# Downloading:  76%|███████▌  | 362M/478M [00:06<00:02, 57.6MB/s]
# Downloading:  77%|███████▋  | 368M/478M [00:07<00:02, 57.7MB/s]
# Downloading:  78%|███████▊  | 373M/478M [00:07<00:02, 54.3MB/s]
# Downloading:  79%|███████▉  | 379M/478M [00:07<00:01, 52.4MB/s]
# Downloading:  80%|████████  | 384M/478M [00:07<00:02, 46.5MB/s]
# Downloading:  81%|████████▏ | 389M/478M [00:07<00:01, 48.0MB/s]
# Downloading:  82%|████████▏ | 393M/478M [00:07<00:01, 46.3MB/s]
# Downloading:  83%|████████▎ | 398M/478M [00:07<00:01, 47.6MB/s]
# Downloading:  85%|████████▍ | 404M/478M [00:07<00:01, 51.8MB/s]
# Downloading:  86%|████████▌ | 409M/478M [00:08<00:01, 47.4MB/s]
# Downloading:  87%|████████▋ | 414M/478M [00:08<00:01, 42.7MB/s]
# Downloading:  88%|████████▊ | 418M/478M [00:08<00:01, 44.0MB/s]
# Downloading:  89%|████████▊ | 423M/478M [00:08<00:01, 45.6MB/s]
# Downloading:  90%|████████▉ | 428M/478M [00:08<00:01, 47.8MB/s]
# Downloading:  91%|█████████ | 433M/478M [00:08<00:00, 48.0MB/s]
# Downloading:  92%|█████████▏| 438M/478M [00:08<00:00, 49.4MB/s]
# Downloading:  93%|█████████▎| 443M/478M [00:08<00:00, 44.7MB/s]
# Downloading:  94%|█████████▎| 447M/478M [00:08<00:00, 43.3MB/s]
# Downloading:  94%|█████████▍| 452M/478M [00:09<00:00, 44.5MB/s]
# Downloading:  96%|█████████▌| 456M/478M [00:09<00:00, 46.2MB/s]
# Downloading:  96%|█████████▋| 461M/478M [00:09<00:00, 45.6MB/s]
# Downloading:  98%|█████████▊| 466M/478M [00:09<00:00, 47.9MB/s]
# Downloading:  99%|█████████▊| 471M/478M [00:09<00:00, 49.3MB/s]
# Downloading: 100%|██████████| 478M/478M [00:09<00:00, 52.4MB/s]
# (train_function pid=372) Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# (train_function pid=372) - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_function pid=372) - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# == Status ==
# Current time: 2022-04-18 13:57:08 (running for 00:00:17.33)
# Memory usage on this node: 3.8/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# == Status ==
# Current time: 2022-04-18 13:57:14 (running for 00:00:22.87)
# Memory usage on this node: 4.5/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# == Status ==
# Current time: 2022-04-18 13:57:19 (running for 00:00:28.28)
# Memory usage on this node: 5.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# (train_function pid=372) is GPU available? True
# (train_function pid=372) device used: cuda:0
# (train_function pid=372) /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_function pid=372)   FutureWarning,
# (train_function pid=372) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:92: SettingWithCopyWarning:
# (train_function pid=372) A value is trying to be set on a copy of a slice from a DataFrame
# (train_function pid=372)
# (train_function pid=372) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (train_function pid=372)   type=int,
# (train_function pid=372) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:93: SettingWithCopyWarning:
# (train_function pid=372) A value is trying to be set on a copy of a slice from a DataFrame
# (train_function pid=372)
# (train_function pid=372) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (train_function pid=372)   help="the port of the node's metric agent.")
# (train_function pid=372) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:94: SettingWithCopyWarning:
# (train_function pid=372) A value is trying to be set on a copy of a slice from a DataFrame
# (train_function pid=372)
# (train_function pid=372) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (train_function pid=372)   parser.add_argument(
# == Status ==
# Current time: 2022-04-18 13:57:25 (running for 00:00:33.78)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# == Status ==
# Current time: 2022-04-18 13:57:30 (running for 00:00:39.19)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# == Status ==
# Current time: 2022-04-18 13:57:36 (running for 00:00:44.62)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# == Status ==
# Current time: 2022-04-18 13:57:41 (running for 00:00:50.03)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# (train_function pid=372) 3257
# (train_function pid=372) Epoch: 1, batch no: 1 loss: 1.40, accuracy: 9.38%
# (train_function pid=372) Epoch: 1, batch no: 11 loss: 1.27, accuracy: 9.66%
# == Status ==
# Current time: 2022-04-18 13:57:46 (running for 00:00:55.44)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# (train_function pid=372) Epoch: 1, batch no: 21 loss: 0.66, accuracy: 16.22%
# (train_function pid=372) Epoch: 1, batch no: 31 loss: 0.44, accuracy: 25.71%
# == Status ==
# Current time: 2022-04-18 13:57:52 (running for 00:01:00.85)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# (train_function pid=372) Epoch: 1, batch no: 41 loss: 0.31, accuracy: 29.88%
# (train_function pid=372) Epoch: 1, batch no: 51 loss: 0.24, accuracy: 33.15%
# == Status ==
# Current time: 2022-04-18 13:57:57 (running for 00:01:06.25)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# (train_function pid=372) Epoch: 1, batch no: 61 loss: 0.19, accuracy: 35.19%
# (train_function pid=372) Epoch: 1, batch no: 71 loss: 0.15, accuracy: 37.98%
# == Status ==
# Current time: 2022-04-18 13:58:03 (running for 00:01:11.66)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# (train_function pid=372) Epoch: 1, batch no: 81 loss: 0.11, accuracy: 42.21%
# (train_function pid=372) Epoch: 1, batch no: 91 loss: 0.09, accuracy: 45.33%
# == Status ==
# Current time: 2022-04-18 13:58:08 (running for 00:01:17.08)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
#
#
# (train_function pid=372) Epoch: 1, batch no: 101 loss: 0.08, accuracy: 47.74%
# (train_function pid=372) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=372) Start Validating
# (train_function pid=372) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=372) Epoch: 1, batch no: 1 loss: 0.62, accuracy: 75.00%
# (train_function pid=372) Epoch: 1, batch no: 11 loss: 0.66, accuracy: 74.15%
# (train_function pid=372) checkpoint path : /root/ray_results/train_function_2022-04-18_13-56-51/train_function_65d6f_00000_0_lr=1.3149e-05_2022-04-18_13-56-52/checkpoint_000000/checkpoint
# == Status ==
# Current time: 2022-04-18 13:58:14 (running for 00:01:22.62)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+
# | Trial name                 | status   | loc            |          lr |
# |----------------------------+----------+----------------+-------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |
# +----------------------------+----------+----------------+-------------+
# 2022-04-18 13:58:15,347	WARNING ray_trial_executor.py:691 -- Over the last 60 seconds, the Tune event loop has been backlogged processing new results. Consider increasing your period of result reporting to improve performance.
# Result for train_function_65d6f_00000:
#   accuracy: 0.732620320855615
#   date: 2022-04-18_13-58-15
#   done: false
#   experiment_id: ea5468e918b54615ab9351e6b10ba1c7
#   hostname: 61cce19fbac7
#   iterations_since_restore: 1
#   loss: 0.739229199786981
#   node_ip: 172.28.0.2
#   pid: 372
#   should_checkpoint: true
#   time_since_restore: 79.35406732559204
#   time_this_iter_s: 79.35406732559204
#   time_total_s: 79.35406732559204
#   timestamp: 1650290295
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 65d6f_00000
#
# (train_function pid=372) Model Saved!
# (train_function pid=372) Epoch: 2, batch no: 1 loss: 0.62, accuracy: 81.25%
# (train_function pid=372) Epoch: 2, batch no: 11 loss: 0.60, accuracy: 78.12%
# == Status ==
# Current time: 2022-04-18 13:58:19 (running for 00:01:28.23)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.739229 |    0.73262 |                    1 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=372) Epoch: 2, batch no: 21 loss: 0.27, accuracy: 80.51%
# (train_function pid=372) Epoch: 2, batch no: 31 loss: 0.19, accuracy: 80.54%
# == Status ==
# Current time: 2022-04-18 13:58:25 (running for 00:01:33.63)
# Memory usage on this node: 5.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.739229 |    0.73262 |                    1 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=372) Epoch: 2, batch no: 41 loss: 0.14, accuracy: 80.41%
# (train_function pid=372) Epoch: 2, batch no: 51 loss: 0.11, accuracy: 80.64%
# == Status ==
# Current time: 2022-04-18 13:58:30 (running for 00:01:39.15)
# Memory usage on this node: 4.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.739229 |    0.73262 |                    1 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=372) Epoch: 2, batch no: 61 loss: 0.09, accuracy: 81.05%
# (train_function pid=372) Epoch: 2, batch no: 71 loss: 0.09, accuracy: 80.63%
# == Status ==
# Current time: 2022-04-18 13:58:36 (running for 00:01:44.57)
# Memory usage on this node: 4.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.739229 |    0.73262 |                    1 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=372) Epoch: 2, batch no: 81 loss: 0.06, accuracy: 81.02%
# (train_function pid=372) Epoch: 2, batch no: 91 loss: 0.05, accuracy: 81.32%
# == Status ==
# Current time: 2022-04-18 13:58:41 (running for 00:01:49.97)
# Memory usage on this node: 4.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.739229 |    0.73262 |                    1 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=372) Epoch: 2, batch no: 101 loss: 0.05, accuracy: 81.50%
# (train_function pid=372) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=372) Start Validating
# (train_function pid=372) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=372) Epoch: 2, batch no: 1 loss: 0.42, accuracy: 81.25%
# (train_function pid=372) Epoch: 2, batch no: 11 loss: 0.56, accuracy: 79.83%
# (train_function pid=372) checkpoint path : /root/ray_results/train_function_2022-04-18_13-56-51/train_function_65d6f_00000_0_lr=1.3149e-05_2022-04-18_13-56-52/checkpoint_000001/checkpoint
# == Status ==
# Current time: 2022-04-18 13:58:46 (running for 00:01:55.38)
# Memory usage on this node: 4.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.739229 |    0.73262 |                    1 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# Result for train_function_65d6f_00000:
#   accuracy: 0.7914438502673797
#   date: 2022-04-18_13-58-49
#   done: false
#   experiment_id: ea5468e918b54615ab9351e6b10ba1c7
#   hostname: 61cce19fbac7
#   iterations_since_restore: 2
#   loss: 0.6141619235277176
#   node_ip: 172.28.0.2
#   pid: 372
#   should_checkpoint: true
#   time_since_restore: 113.32982182502747
#   time_this_iter_s: 33.975754499435425
#   time_total_s: 113.32982182502747
#   timestamp: 1650290329
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 65d6f_00000
#
# (train_function pid=372) Model Saved!
# (train_function pid=372) Epoch: 3, batch no: 1 loss: 0.39, accuracy: 81.25%
# == Status ==
# Current time: 2022-04-18 13:58:52 (running for 00:02:01.03)
# Memory usage on this node: 4.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.7914438502673797 | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.614162 |   0.791444 |                    2 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=372) Epoch: 3, batch no: 11 loss: 0.28, accuracy: 88.92%
# (train_function pid=372) Epoch: 3, batch no: 21 loss: 0.14, accuracy: 89.14%
# == Status ==
# Current time: 2022-04-18 13:58:57 (running for 00:02:06.42)
# Memory usage on this node: 4.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.7914438502673797 | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.614162 |   0.791444 |                    2 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=372) Epoch: 3, batch no: 31 loss: 0.10, accuracy: 89.21%
# (train_function pid=372) Epoch: 3, batch no: 41 loss: 0.09, accuracy: 88.64%
# == Status ==
# Current time: 2022-04-18 13:59:03 (running for 00:02:11.92)
# Memory usage on this node: 4.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.7914438502673797 | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | RUNNING  | 172.28.0.2:372 | 1.31485e-05 | 0.614162 |   0.791444 |                    2 |
# | train_function_65d6f_00001 | PENDING  |                | 0.000131724 |          |            |                      |
# | train_function_65d6f_00002 | PENDING  |                | 7.06812e-05 |          |            |                      |
# | train_function_65d6f_00003 | PENDING  |                | 4.65563e-05 |          |            |                      |
# | train_function_65d6f_00004 | PENDING  |                | 2.73563e-05 |          |            |                      |
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=372) Epoch: 3, batch no: 51 loss: 0.06, accuracy: 89.09%
# (train_function pid=372) Epoch: 3, batch no: 61 loss: 0.07, accuracy: 88.32%
# == Status ==
# Current time: 2022-04-18 13:59:08 (running for 00:02:17.31)
# Memory usage on this node: 4.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.7914438502673797 | Iter 1.000: 0.732620320855615
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+-------------+----------+------------+----------------------+
# ...
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status     | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00004 | RUNNING    | 172.28.0.2:595 | 2.73563e-05 |          |            |                      |
# | train_function_65d6f_00000 | TERMINATED | 172.28.0.2:372 | 1.31485e-05 | 0.883928 |   0.81016  |                   10 |
# | train_function_65d6f_00001 | TERMINATED | 172.28.0.2:375 | 0.000131724 | 0.795531 |   0.719251 |                    1 |
# | train_function_65d6f_00002 | TERMINATED | 172.28.0.2:374 | 7.06812e-05 | 0.653326 |   0.78877  |                    2 |
# | train_function_65d6f_00003 | TERMINATED | 172.28.0.2:373 | 4.65563e-05 | 0.639779 |   0.772727 |                    2 |
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=595) Epoch: 1, batch no: 41 loss: 0.31, accuracy: 32.70%
# == Status ==
# Current time: 2022-04-18 14:08:58 (running for 00:12:07.27)
# Memory usage on this node: 4.4/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8048128342245989 | Iter 4.000: 0.8048128342245989 | Iter 2.000: 0.7887700534759359 | Iter 1.000: 0.7419786096256684
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status     | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00004 | RUNNING    | 172.28.0.2:595 | 2.73563e-05 |          |            |                      |
# | train_function_65d6f_00000 | TERMINATED | 172.28.0.2:372 | 1.31485e-05 | 0.883928 |   0.81016  |                   10 |
# | train_function_65d6f_00001 | TERMINATED | 172.28.0.2:375 | 0.000131724 | 0.795531 |   0.719251 |                    1 |
# | train_function_65d6f_00002 | TERMINATED | 172.28.0.2:374 | 7.06812e-05 | 0.653326 |   0.78877  |                    2 |
# | train_function_65d6f_00003 | TERMINATED | 172.28.0.2:373 | 4.65563e-05 | 0.639779 |   0.772727 |                    2 |
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=595) Epoch: 1, batch no: 51 loss: 0.22, accuracy: 36.46%
# (train_function pid=595) Epoch: 1, batch no: 61 loss: 0.15, accuracy: 41.39%
# == Status ==
# Current time: 2022-04-18 14:09:03 (running for 00:12:12.28)
# Memory usage on this node: 4.4/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8048128342245989 | Iter 4.000: 0.8048128342245989 | Iter 2.000: 0.7887700534759359 | Iter 1.000: 0.7419786096256684
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status     | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00004 | RUNNING    | 172.28.0.2:595 | 2.73563e-05 |          |            |                      |
# | train_function_65d6f_00000 | TERMINATED | 172.28.0.2:372 | 1.31485e-05 | 0.883928 |   0.81016  |                   10 |
# | train_function_65d6f_00001 | TERMINATED | 172.28.0.2:375 | 0.000131724 | 0.795531 |   0.719251 |                    1 |
# | train_function_65d6f_00002 | TERMINATED | 172.28.0.2:374 | 7.06812e-05 | 0.653326 |   0.78877  |                    2 |
# | train_function_65d6f_00003 | TERMINATED | 172.28.0.2:373 | 4.65563e-05 | 0.639779 |   0.772727 |                    2 |
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=595) Epoch: 1, batch no: 71 loss: 0.12, accuracy: 45.42%
# (train_function pid=595) Epoch: 1, batch no: 81 loss: 0.09, accuracy: 49.00%
# == Status ==
# Current time: 2022-04-18 14:09:08 (running for 00:12:17.28)
# Memory usage on this node: 4.4/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8048128342245989 | Iter 4.000: 0.8048128342245989 | Iter 2.000: 0.7887700534759359 | Iter 1.000: 0.7419786096256684
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status     | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00004 | RUNNING    | 172.28.0.2:595 | 2.73563e-05 |          |            |                      |
# | train_function_65d6f_00000 | TERMINATED | 172.28.0.2:372 | 1.31485e-05 | 0.883928 |   0.81016  |                   10 |
# | train_function_65d6f_00001 | TERMINATED | 172.28.0.2:375 | 0.000131724 | 0.795531 |   0.719251 |                    1 |
# | train_function_65d6f_00002 | TERMINATED | 172.28.0.2:374 | 7.06812e-05 | 0.653326 |   0.78877  |                    2 |
# | train_function_65d6f_00003 | TERMINATED | 172.28.0.2:373 | 4.65563e-05 | 0.639779 |   0.772727 |                    2 |
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=595) Epoch: 1, batch no: 91 loss: 0.07, accuracy: 51.89%
# (train_function pid=595) Epoch: 1, batch no: 101 loss: 0.07, accuracy: 54.18%
# (train_function pid=595) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=595) Start Validating
# (train_function pid=595) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=595) Epoch: 1, batch no: 1 loss: 0.57, accuracy: 81.25%
# == Status ==
# Current time: 2022-04-18 14:09:13 (running for 00:12:22.29)
# Memory usage on this node: 4.4/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8048128342245989 | Iter 4.000: 0.8048128342245989 | Iter 2.000: 0.7887700534759359 | Iter 1.000: 0.7419786096256684
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status     | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00004 | RUNNING    | 172.28.0.2:595 | 2.73563e-05 |          |            |                      |
# | train_function_65d6f_00000 | TERMINATED | 172.28.0.2:372 | 1.31485e-05 | 0.883928 |   0.81016  |                   10 |
# | train_function_65d6f_00001 | TERMINATED | 172.28.0.2:375 | 0.000131724 | 0.795531 |   0.719251 |                    1 |
# | train_function_65d6f_00002 | TERMINATED | 172.28.0.2:374 | 7.06812e-05 | 0.653326 |   0.78877  |                    2 |
# | train_function_65d6f_00003 | TERMINATED | 172.28.0.2:373 | 4.65563e-05 | 0.639779 |   0.772727 |                    2 |
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
#
#
# (train_function pid=595) Epoch: 1, batch no: 11 loss: 0.71, accuracy: 73.30%
# (train_function pid=595) checkpoint path : /root/ray_results/train_function_2022-04-18_13-56-51/train_function_65d6f_00004_4_lr=2.7356e-05_2022-04-18_14-06-32/checkpoint_000000/checkpoint
# == Status ==
# Current time: 2022-04-18 14:09:18 (running for 00:12:27.30)
# Memory usage on this node: 4.4/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8048128342245989 | Iter 4.000: 0.8048128342245989 | Iter 2.000: 0.7887700534759359 | Iter 1.000: 0.7419786096256684
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status     | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00004 | RUNNING    | 172.28.0.2:595 | 2.73563e-05 |          |            |                      |
# | train_function_65d6f_00000 | TERMINATED | 172.28.0.2:372 | 1.31485e-05 | 0.883928 |   0.81016  |                   10 |
# | train_function_65d6f_00001 | TERMINATED | 172.28.0.2:375 | 0.000131724 | 0.795531 |   0.719251 |                    1 |
# | train_function_65d6f_00002 | TERMINATED | 172.28.0.2:374 | 7.06812e-05 | 0.653326 |   0.78877  |                    2 |
# | train_function_65d6f_00003 | TERMINATED | 172.28.0.2:373 | 4.65563e-05 | 0.639779 |   0.772727 |                    2 |
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
#
#
# Result for train_function_65d6f_00004:
#   accuracy: 0.7272727272727273
#   date: 2022-04-18_14-09-19
#   done: true
#   experiment_id: f3b81d1c88a24463b91dc4f26f1f97eb
#   hostname: 61cce19fbac7
#   iterations_since_restore: 1
#   loss: 0.7744197994470596
#   node_ip: 172.28.0.2
#   pid: 595
#   should_checkpoint: true
#   time_since_restore: 59.60444736480713
#   time_this_iter_s: 59.60444736480713
#   time_total_s: 59.60444736480713
#   timestamp: 1650290959
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 65d6f_00004
# 2022-04-18 14:09:19,708	INFO tune.py:636 -- Total run time: 748.30 seconds (747.82 seconds for the tuning loop).
# (train_function pid=595) Model Saved!
# == Status ==
# Current time: 2022-04-18 14:09:19 (running for 00:12:28.06)
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 8.000: 0.8048128342245989 | Iter 4.000: 0.8048128342245989 | Iter 2.000: 0.7887700534759359 | Iter 1.000: 0.732620320855615
# Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/14.54 GiB heap, 0.0/7.27 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-56-51
# Number of trials: 5/5 (5 TERMINATED)
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
# | Trial name                 | status     | loc            |          lr |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+----------------+-------------+----------+------------+----------------------|
# | train_function_65d6f_00000 | TERMINATED | 172.28.0.2:372 | 1.31485e-05 | 0.883928 |   0.81016  |                   10 |
# | train_function_65d6f_00001 | TERMINATED | 172.28.0.2:375 | 0.000131724 | 0.795531 |   0.719251 |                    1 |
# | train_function_65d6f_00002 | TERMINATED | 172.28.0.2:374 | 7.06812e-05 | 0.653326 |   0.78877  |                    2 |
# | train_function_65d6f_00003 | TERMINATED | 172.28.0.2:373 | 4.65563e-05 | 0.639779 |   0.772727 |                    2 |
# | train_function_65d6f_00004 | TERMINATED | 172.28.0.2:595 | 2.73563e-05 | 0.77442  |   0.727273 |                    1 |
# +----------------------------+------------+----------------+-------------+----------+------------+----------------------+
#
#
# Best trial config for learning rate: {'num_epochs': 10, 'lr': 1.3148523992259347e-05, 'batch_size': 32, 'weight_decay': 0.1, 'beta1': 0.9, 'beta2': 0.98, 'eps': 1e-06, 'max_gradient_norm': 10, 'dropout': 0.1, 'warmup': 0.06, 'd_h': 512, 'max_length': 50}
# Best trial final validation loss: 0.8839278245965639
# Best trial final validation accuracy: 0.8101604278074866
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 3257
# Best trial test set accuracy: 0.8177339901477833 , test loss : 0.8335969775915146
# scheduler : dict_keys(['base_lrs', 'last_epoch', '_step_count', 'verbose', '_get_lr_called_within_step', '_last_lr', 'lr_lambdas'])

# %%
# Weight decay
config = {"num_epochs": 10,
          "lr": 3e-5,
          "batch_size": 32,
          "weight_decay": tune.loguniform(5e-5,1e-2),
          "beta1": 0.9,
          "beta2": 0.98,
          "eps": 1e-6,
          "max_gradient_norm":10,
          "dropout": 0.1,
          "warmup":0.06,
          "d_h":512,
          "max_length": 50
          }

# %%
def main(num_samples=10,max_num_epochs =10, gpus_per_trial=1):

    reporter = CLIReporter(metric_columns=["loss", "accuracy", "training_iteration"])

    ## ASHA scheduler
    scheduler = ASHAScheduler(
        metric="accuracy",
        mode="max",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    
    result = tune.run(
        train_function,
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter = reporter,
        )

    best_trial = result.get_best_trial("accuracy", "max", "last")
    print("Best trial config for weight decay: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    best_trained_model = RobertaModel.from_pretrained(model_name,config = config_model)
    best_trained_model = FinetuneModel(best_trained_model,d_in,best_trial.config['d_h'],d_out,best_trial.config['dropout'],freeze_pretrained)
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state,scheduler_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_acc,test_loss = test_accuracy(best_trial.config,best_trained_model, device)
    print("Best trial test set accuracy: {} , test loss : {}".format(test_acc,test_loss))
    print (f'scheduler : {scheduler_state.keys()}')


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=5,max_num_epochs=10, gpus_per_trial=1)
# Out:
# 2022-04-18 13:13:58,008	WARNING callback.py:115 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-04-18 13:13:58 (running for 00:00:00.59)
# Memory usage on this node: 4.5/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (5 PENDING)
# +----------------------------+----------+-------+----------------+
# | Trial name                 | status   | loc   |   weight_decay |
# |----------------------------+----------+-------+----------------|
# | train_function_67e97_00000 | PENDING  |       |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |       |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |       |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |       |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |       |    0.00021567  |
# +----------------------------+----------+-------+----------------+
#
#
# == Status ==
# Current time: 2022-04-18 13:14:03 (running for 00:00:05.63)
# Memory usage on this node: 5.1/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
# (train_function pid=717) Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight']
# (train_function pid=717) - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_function pid=717) - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# == Status ==
# Current time: 2022-04-18 13:14:09 (running for 00:00:11.60)
# Memory usage on this node: 7.6/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# (train_function pid=717) is GPU available? True
# (train_function pid=717) device used: cuda:0
# (train_function pid=717) /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_function pid=717)   FutureWarning,
# (train_function pid=717) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:92: SettingWithCopyWarning:
# (train_function pid=717) A value is trying to be set on a copy of a slice from a DataFrame
# (train_function pid=717)
# (train_function pid=717) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (train_function pid=717)   type=int,
# (train_function pid=717) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:93: SettingWithCopyWarning:
# (train_function pid=717) A value is trying to be set on a copy of a slice from a DataFrame
# (train_function pid=717)
# (train_function pid=717) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (train_function pid=717)   help="the port of the node's metric agent.")
# (train_function pid=717) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:94: SettingWithCopyWarning:
# (train_function pid=717) A value is trying to be set on a copy of a slice from a DataFrame
# (train_function pid=717)
# (train_function pid=717) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (train_function pid=717)   parser.add_argument(
# == Status ==
# Current time: 2022-04-18 13:14:15 (running for 00:00:17.00)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# == Status ==
# Current time: 2022-04-18 13:14:20 (running for 00:00:22.42)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# == Status ==
# Current time: 2022-04-18 13:14:25 (running for 00:00:27.82)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# (train_function pid=717) 3257
# (train_function pid=717) Epoch: 1, batch no: 1 loss: 1.40, accuracy: 9.38%
# == Status ==
# Current time: 2022-04-18 13:14:31 (running for 00:00:33.22)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# (train_function pid=717) Epoch: 1, batch no: 11 loss: 1.27, accuracy: 11.08%
# (train_function pid=717) Epoch: 1, batch no: 21 loss: 0.65, accuracy: 22.62%
# == Status ==
# Current time: 2022-04-18 13:14:36 (running for 00:00:38.62)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# (train_function pid=717) Epoch: 1, batch no: 31 loss: 0.41, accuracy: 29.84%
# (train_function pid=717) Epoch: 1, batch no: 41 loss: 0.30, accuracy: 33.08%
# == Status ==
# Current time: 2022-04-18 13:14:42 (running for 00:00:44.03)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# (train_function pid=717) Epoch: 1, batch no: 51 loss: 0.21, accuracy: 37.68%
# (train_function pid=717) Epoch: 1, batch no: 61 loss: 0.15, accuracy: 42.37%
# == Status ==
# Current time: 2022-04-18 13:14:47 (running for 00:00:49.42)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# (train_function pid=717) Epoch: 1, batch no: 71 loss: 0.11, accuracy: 46.43%
# == Status ==
# Current time: 2022-04-18 13:14:52 (running for 00:00:54.92)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# (train_function pid=717) Epoch: 1, batch no: 81 loss: 0.09, accuracy: 49.65%
# (train_function pid=717) Epoch: 1, batch no: 91 loss: 0.07, accuracy: 52.68%
# == Status ==
# Current time: 2022-04-18 13:14:58 (running for 00:01:00.33)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
#
#
# (train_function pid=717) Epoch: 1, batch no: 101 loss: 0.07, accuracy: 54.92%
# (train_function pid=717) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=717) Start Validating
# (train_function pid=717) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=717) Epoch: 1, batch no: 1 loss: 0.53, accuracy: 78.12%
# (train_function pid=717) Epoch: 1, batch no: 11 loss: 0.58, accuracy: 75.85%
# (train_function pid=717) checkpoint path : /root/ray_results/train_function_2022-04-18_13-13-58/train_function_67e97_00000_0_weight_decay=0.00016832_2022-04-18_13-13-58/checkpoint_000000/checkpoint
# == Status ==
# Current time: 2022-04-18 13:15:04 (running for 00:01:06.94)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+
# | Trial name                 | status   | loc            |   weight_decay |
# |----------------------------+----------+----------------+----------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |
# +----------------------------+----------+----------------+----------------+
# 2022-04-18 13:15:06,159	WARNING ray_trial_executor.py:691 -- Over the last 60 seconds, the Tune event loop has been backlogged processing new results. Consider increasing your period of result reporting to improve performance.
# Result for train_function_67e97_00000:
#   accuracy: 0.7540106951871658
#   date: 2022-04-18_13-15-06
#   done: false
#   experiment_id: c8de44d7ee90482ab42fb4092900d909
#   hostname: e0bfa5da12ae
#   iterations_since_restore: 1
#   loss: 0.6306526536742846
#   node_ip: 172.28.0.2
#   pid: 717
#   should_checkpoint: true
#   time_since_restore: 62.268256187438965
#   time_this_iter_s: 62.268256187438965
#   time_total_s: 62.268256187438965
#   timestamp: 1650287706
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 67e97_00000
#
# (train_function pid=717) Model Saved!
# (train_function pid=717) Epoch: 2, batch no: 1 loss: 0.52, accuracy: 78.12%
# (train_function pid=717) Epoch: 2, batch no: 11 loss: 0.51, accuracy: 79.83%
# == Status ==
# Current time: 2022-04-18 13:15:10 (running for 00:01:12.63)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.630653 |   0.754011 |                    1 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 2, batch no: 21 loss: 0.20, accuracy: 83.18%
# (train_function pid=717) Epoch: 2, batch no: 31 loss: 0.15, accuracy: 83.67%
# == Status ==
# Current time: 2022-04-18 13:15:16 (running for 00:01:18.05)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.630653 |   0.754011 |                    1 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 2, batch no: 41 loss: 0.11, accuracy: 84.15%
# == Status ==
# Current time: 2022-04-18 13:15:21 (running for 00:01:23.46)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.630653 |   0.754011 |                    1 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 2, batch no: 51 loss: 0.09, accuracy: 84.01%
# (train_function pid=717) Epoch: 2, batch no: 61 loss: 0.07, accuracy: 84.43%
# == Status ==
# Current time: 2022-04-18 13:15:26 (running for 00:01:28.86)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.630653 |   0.754011 |                    1 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 2, batch no: 71 loss: 0.07, accuracy: 84.24%
# (train_function pid=717) Epoch: 2, batch no: 81 loss: 0.05, accuracy: 84.34%
# == Status ==
# Current time: 2022-04-18 13:15:32 (running for 00:01:34.25)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.630653 |   0.754011 |                    1 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 2, batch no: 91 loss: 0.04, accuracy: 84.65%
# (train_function pid=717) Epoch: 2, batch no: 101 loss: 0.04, accuracy: 84.72%
# (train_function pid=717) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=717) Start Validating
# (train_function pid=717) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=717) Epoch: 2, batch no: 1 loss: 0.47, accuracy: 81.25%
# == Status ==
# Current time: 2022-04-18 13:15:37 (running for 00:01:39.68)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.630653 |   0.754011 |                    1 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 2, batch no: 11 loss: 0.52, accuracy: 81.53%
# (train_function pid=717) checkpoint path : /root/ray_results/train_function_2022-04-18_13-13-58/train_function_67e97_00000_0_weight_decay=0.00016832_2022-04-18_13-13-58/checkpoint_000001/checkpoint
# Result for train_function_67e97_00000:
#   accuracy: 0.8128342245989305
#   date: 2022-04-18_13-15-43
#   done: false
#   experiment_id: c8de44d7ee90482ab42fb4092900d909
#   hostname: e0bfa5da12ae
#   iterations_since_restore: 2
#   loss: 0.5929253349701563
#   node_ip: 172.28.0.2
#   pid: 717
#   should_checkpoint: true
#   time_since_restore: 99.35311698913574
#   time_this_iter_s: 37.08486080169678
#   time_total_s: 99.35311698913574
#   timestamp: 1650287743
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 67e97_00000
#
# == Status ==
# Current time: 2022-04-18 13:15:43 (running for 00:01:45.22)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.592925 |   0.812834 |                    2 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Model Saved!
# (train_function pid=717) Epoch: 3, batch no: 1 loss: 0.19, accuracy: 90.62%
# (train_function pid=717) Epoch: 3, batch no: 11 loss: 0.18, accuracy: 94.03%
# == Status ==
# Current time: 2022-04-18 13:15:48 (running for 00:01:50.85)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.592925 |   0.812834 |                    2 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 3, batch no: 21 loss: 0.07, accuracy: 95.24%
# (train_function pid=717) Epoch: 3, batch no: 31 loss: 0.05, accuracy: 95.46%
# == Status ==
# Current time: 2022-04-18 13:15:54 (running for 00:01:56.27)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.592925 |   0.812834 |                    2 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 3, batch no: 41 loss: 0.07, accuracy: 94.44%
# (train_function pid=717) Epoch: 3, batch no: 51 loss: 0.05, accuracy: 93.81%
# == Status ==
# Current time: 2022-04-18 13:15:59 (running for 00:02:01.69)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.592925 |   0.812834 |                    2 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 3, batch no: 61 loss: 0.05, accuracy: 93.03%
# (train_function pid=717) Epoch: 3, batch no: 71 loss: 0.02, accuracy: 93.49%
# == Status ==
# Current time: 2022-04-18 13:16:05 (running for 00:02:07.11)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.592925 |   0.812834 |                    2 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 3, batch no: 81 loss: 0.03, accuracy: 93.52%
# == Status ==
# Current time: 2022-04-18 13:16:10 (running for 00:02:12.54)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.592925 |   0.812834 |                    2 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=717) Epoch: 3, batch no: 91 loss: 0.02, accuracy: 93.58%
# (train_function pid=717) Epoch: 3, batch no: 101 loss: 0.02, accuracy: 93.47%
# (train_function pid=717) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=717) Start Validating
# (train_function pid=717) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=717) Epoch: 3, batch no: 1 loss: 0.50, accuracy: 81.25%
# (train_function pid=717) Epoch: 3, batch no: 11 loss: 0.52, accuracy: 81.53%
# (train_function pid=717) checkpoint path : /root/ray_results/train_function_2022-04-18_13-13-58/train_function_67e97_00000_0_weight_decay=0.00016832_2022-04-18_13-13-58/checkpoint_000002/checkpoint
# == Status ==
# Current time: 2022-04-18 13:16:15 (running for 00:02:17.94)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status   | loc            |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+----------+----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | RUNNING  | 172.28.0.2:717 |    0.000168318 | 0.592925 |   0.812834 |                    2 |
# | train_function_67e97_00001 | PENDING  |                |    0.000390404 |          |            |                      |
# | train_function_67e97_00002 | PENDING  |                |    5.34784e-05 |          |            |                      |
# | train_function_67e97_00003 | PENDING  |                |    0.000613022 |          |            |                      |
# | train_function_67e97_00004 | PENDING  |                |    0.00021567  |          |            |                      |
# +----------------------------+----------+----------------+----------------+----------+------------+----------------------+
#
#
# Result for train_function_67e97_00000:
#   accuracy: 0.8101604278074866
#   date: 2022-04-18_13-16-20
#   done: false
#   experiment_id: c8de44d7ee90482ab42fb4092900d909
#   hostname: e0bfa5da12ae
#   iterations_since_restore: 3
#   loss: 0.5864216933647791
#   node_ip: 172.28.0.2
#   pid: 717
#   should_checkpoint: true
#   time_since_restore: 136.78466272354126
#   time_this_iter_s: 37.43154573440552
#   time_total_s: 136.78466272354126
#   timestamp: 1650287780
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: 67e97_00000
#
# (train_function pid=717) Model Saved!
# (train_function pid=717) Epoch: 4, batch no: 1 loss: 0.15, accuracy: 93.75%
# == Status ==
# Current time: 2022-04-18 13:16:22 (running for 00:02:24.07)
# Memory usage on this node: 7.2/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# ...
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status     | loc             |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+-----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00004 | RUNNING    | 172.28.0.2:1046 |    0.00021567  | 0.902191 |   0.828877 |                    9 |
# | train_function_67e97_00000 | TERMINATED | 172.28.0.2:717  |    0.000168318 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00001 | TERMINATED | 172.28.0.2:716  |    0.000390404 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00002 | TERMINATED | 172.28.0.2:880  |    5.34784e-05 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00003 | TERMINATED | 172.28.0.2:994  |    0.000613022 | 0.922333 |   0.826203 |                   10 |
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=1046) Epoch: 10, batch no: 41 loss: 0.00, accuracy: 99.92%
# == Status ==
# Current time: 2022-04-18 13:47:25 (running for 00:33:27.86)
# Memory usage on this node: 9.7/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8155080213903744 | Iter 4.000: 0.8181818181818182 | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status     | loc             |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+-----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00004 | RUNNING    | 172.28.0.2:1046 |    0.00021567  | 0.902191 |   0.828877 |                    9 |
# | train_function_67e97_00000 | TERMINATED | 172.28.0.2:717  |    0.000168318 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00001 | TERMINATED | 172.28.0.2:716  |    0.000390404 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00002 | TERMINATED | 172.28.0.2:880  |    5.34784e-05 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00003 | TERMINATED | 172.28.0.2:994  |    0.000613022 | 0.922333 |   0.826203 |                   10 |
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=1046) Epoch: 10, batch no: 51 loss: 0.00, accuracy: 99.94%
# (train_function pid=1046) Epoch: 10, batch no: 61 loss: 0.00, accuracy: 99.95%
# == Status ==
# Current time: 2022-04-18 13:47:30 (running for 00:33:32.86)
# Memory usage on this node: 9.7/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8155080213903744 | Iter 4.000: 0.8181818181818182 | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status     | loc             |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+-----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00004 | RUNNING    | 172.28.0.2:1046 |    0.00021567  | 0.902191 |   0.828877 |                    9 |
# | train_function_67e97_00000 | TERMINATED | 172.28.0.2:717  |    0.000168318 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00001 | TERMINATED | 172.28.0.2:716  |    0.000390404 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00002 | TERMINATED | 172.28.0.2:880  |    5.34784e-05 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00003 | TERMINATED | 172.28.0.2:994  |    0.000613022 | 0.922333 |   0.826203 |                   10 |
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=1046) Epoch: 10, batch no: 71 loss: 0.00, accuracy: 99.96%
# (train_function pid=1046) Epoch: 10, batch no: 81 loss: 0.00, accuracy: 99.96%
# == Status ==
# Current time: 2022-04-18 13:47:35 (running for 00:33:37.87)
# Memory usage on this node: 9.7/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8155080213903744 | Iter 4.000: 0.8181818181818182 | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status     | loc             |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+-----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00004 | RUNNING    | 172.28.0.2:1046 |    0.00021567  | 0.902191 |   0.828877 |                    9 |
# | train_function_67e97_00000 | TERMINATED | 172.28.0.2:717  |    0.000168318 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00001 | TERMINATED | 172.28.0.2:716  |    0.000390404 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00002 | TERMINATED | 172.28.0.2:880  |    5.34784e-05 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00003 | TERMINATED | 172.28.0.2:994  |    0.000613022 | 0.922333 |   0.826203 |                   10 |
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=1046) Epoch: 10, batch no: 91 loss: 0.00, accuracy: 99.97%
# == Status ==
# Current time: 2022-04-18 13:47:40 (running for 00:33:42.88)
# Memory usage on this node: 9.7/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8155080213903744 | Iter 4.000: 0.8181818181818182 | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status     | loc             |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+-----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00004 | RUNNING    | 172.28.0.2:1046 |    0.00021567  | 0.902191 |   0.828877 |                    9 |
# | train_function_67e97_00000 | TERMINATED | 172.28.0.2:717  |    0.000168318 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00001 | TERMINATED | 172.28.0.2:716  |    0.000390404 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00002 | TERMINATED | 172.28.0.2:880  |    5.34784e-05 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00003 | TERMINATED | 172.28.0.2:994  |    0.000613022 | 0.922333 |   0.826203 |                   10 |
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
#
#
# (train_function pid=1046) Epoch: 10, batch no: 101 loss: 0.00, accuracy: 99.97%
# (train_function pid=1046) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=1046) Start Validating
# (train_function pid=1046) ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (train_function pid=1046) Epoch: 10, batch no: 1 loss: 0.55, accuracy: 90.62%
# (train_function pid=1046) Epoch: 10, batch no: 11 loss: 0.83, accuracy: 83.24%
# (train_function pid=1046) checkpoint path : /root/ray_results/train_function_2022-04-18_13-13-58/train_function_67e97_00004_4_weight_decay=0.00021567_2022-04-18_13-34-20/checkpoint_000009/checkpoint
# == Status ==
# Current time: 2022-04-18 13:47:45 (running for 00:33:47.88)
# Memory usage on this node: 9.7/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.8155080213903744 | Iter 4.000: 0.8181818181818182 | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 2.0/4 CPUs, 1.0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status     | loc             |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+-----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00004 | RUNNING    | 172.28.0.2:1046 |    0.00021567  | 0.902191 |   0.828877 |                    9 |
# | train_function_67e97_00000 | TERMINATED | 172.28.0.2:717  |    0.000168318 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00001 | TERMINATED | 172.28.0.2:716  |    0.000390404 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00002 | TERMINATED | 172.28.0.2:880  |    5.34784e-05 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00003 | TERMINATED | 172.28.0.2:994  |    0.000613022 | 0.922333 |   0.826203 |                   10 |
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
#
#
# Result for train_function_67e97_00004:
#   accuracy: 0.8262032085561497
#   date: 2022-04-18_13-47-47
#   done: true
#   experiment_id: d6f1b05c10ea4da19cc1ee6351f96591
#   hostname: e0bfa5da12ae
#   iterations_since_restore: 10
#   loss: 0.9223327934741974
#   node_ip: 172.28.0.2
#   pid: 1046
#   should_checkpoint: true
#   time_since_restore: 395.46760511398315
#   time_this_iter_s: 37.10399389266968
#   time_total_s: 395.46760511398315
#   timestamp: 1650289667
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 67e97_00004
#
# (train_function pid=1046) Model Saved!
# == Status ==
# Current time: 2022-04-18 13:47:48 (running for 00:33:50.08)
# Memory usage on this node: 9.5/25.5 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 8.000: 0.8155080213903744 | Iter 4.000: 0.8181818181818182 | Iter 2.000: 0.8128342245989305 | Iter 1.000: 0.7540106951871658
# Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/13.8 GiB heap, 0.0/6.9 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /root/ray_results/train_function_2022-04-18_13-13-58
# Number of trials: 5/5 (5 TERMINATED)
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
# | Trial name                 | status     | loc             |   weight_decay |     loss |   accuracy |   training_iteration |
# |----------------------------+------------+-----------------+----------------+----------+------------+----------------------|
# | train_function_67e97_00000 | TERMINATED | 172.28.0.2:717  |    0.000168318 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00001 | TERMINATED | 172.28.0.2:716  |    0.000390404 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00002 | TERMINATED | 172.28.0.2:880  |    5.34784e-05 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00003 | TERMINATED | 172.28.0.2:994  |    0.000613022 | 0.922333 |   0.826203 |                   10 |
# | train_function_67e97_00004 | TERMINATED | 172.28.0.2:1046 |    0.00021567  | 0.922333 |   0.826203 |                   10 |
# +----------------------------+------------+-----------------+----------------+----------+------------+----------------------+
# 2022-04-18 13:47:48,195	INFO tune.py:636 -- Total run time: 2030.25 seconds (2029.93 seconds for the tuning loop).
# Best trial config: {'num_epochs': 10, 'lr': 3e-05, 'batch_size': 32, 'weight_decay': 0.00016831797558624405, 'beta1': 0.9, 'beta2': 0.98, 'eps': 1e-06, 'max_gradient_norm': 10, 'dropout': 0.1, 'warmup': 0.06, 'd_h': 512, 'max_length': 50}
# Best trial final validation loss: 0.9223327934741974
# Best trial final validation accuracy: 0.8262032085561497
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 3257
# Best trial test set accuracy: 0.8212526389866291 , test loss : 0.9160932572455042
# scheduler : dict_keys(['base_lrs', 'last_epoch', '_step_count', 'verbose', '_get_lr_called_within_step', '_last_lr', 'lr_lambdas'])

# %%
# Max grad norm
config = {"num_epochs": 10,
          "lr": 3e-5,
          "batch_size": 32,
          "weight_decay": 0.1,
          "beta1": 0.9,
          "beta2": 0.98,
          "eps": 1e-6,
          "max_gradient_norm":tune.randint(0,12),
          "dropout": 0.1,
          "warmup":0.06,
          "d_h":512,
          "max_length": 50
          }

# %%
def main(num_samples=10,max_num_epochs =10, gpus_per_trial=1):

    reporter = CLIReporter(metric_columns=["loss", "accuracy", "training_iteration"])

    ## ASHA scheduler
    scheduler = ASHAScheduler(
        metric="accuracy",
        mode="max",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    
    result = tune.run(
        train_function,
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter = reporter,
        )

    best_trial = result.get_best_trial("accuracy", "max", "last")
    print("Best trial config for max grad norm: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    best_trained_model = RobertaModel.from_pretrained(model_name,config = config_model)
    best_trained_model = FinetuneModel(best_trained_model,d_in,best_trial.config['d_h'],d_out,best_trial.config['dropout'],freeze_pretrained)
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state,scheduler_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_acc,test_loss = test_accuracy(best_trial.config,best_trained_model, device)
    print("Best trial test set accuracy: {} , test loss : {}".format(test_acc,test_loss))
    print (f'scheduler : {scheduler_state.keys()}')


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=5,max_num_epochs=10, gpus_per_trial=1)

# %%
## Tune entire set of hyperparameters
config = {
    "num_epochs": tune.randint(3,10),
    "lr": tune.loguniform(1e-5, 1e-4),
    "batch_size": tune.choice([8,16,32,64]),
    "weight_decay": tune.uniform(0.0, 0.15),
    "beta1" : tune.uniform(0.8,0.95),
    "beta2" : tune.uniform(0.995,0.999),
    "eps": tune.loguniform(1e-8,1e-6),
    "max_gradient_norm": tune.randint(7,12),
    "dropout": tune.choice([0.1,0.2,0.3]),
    "warmup": tune.choice([0.04,0.06,0.08,0.1,0.12]),
    "d_h": tune.choice([128,256,512,1024]),
    "max_length": 50
}

# %%
def main(num_samples=10,max_num_epochs =10, gpus_per_trial=1):
    # load_data()
    # ray.init()
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "accuracy", "training_iteration"])

    ## ASHA scheduler
    scheduler = ASHAScheduler(
        metric="accuracy",
        mode="max",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    
    result = tune.run(
        train_function,
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter = reporter,
        )

    best_trial = result.get_best_trial("accuracy", "max", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    best_trained_model = RobertaModel.from_pretrained(model_name,config = config_model)
    best_trained_model = FinetuneModel(best_trained_model,d_in,best_trial.config['d_h'],d_out,best_trial.config['dropout'],freeze_pretrained)
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state,scheduler_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_acc,test_loss = test_accuracy(best_trial.config,best_trained_model, device)
    print("Best trial test set accuracy: {} , test loss : {}".format(test_acc,test_loss))
    print (f'scheduler : {scheduler_state.keys()}')


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=25,max_num_epochs=10, gpus_per_trial=1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
